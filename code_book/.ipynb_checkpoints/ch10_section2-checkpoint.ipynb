# %%
def main():
    # 학습을 시작함.
    q1_learning()

# %%
import tictactoe

def q1_learning():
    # 전체 강화학습의 훈련 횟수 정의
    N_episodes = 1000
    # 탐험(Exploration) 방법 정의
    epsilon = 0.4
    second_epsilon = 0.1
    epsilon_change_episode = 100 # 탐험 비중 인자 변경 시점
    tictactoe.learning_stage_qlearn(N_episodes=N_episodes, epsilon=epsilon, fig_flag=True)

# %%
main()
# Out:
# 0 [0, 1, 0, 1, 0, 1, 0, 0, 0]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# 100 [12, 42, 47, 65, 24, 33, 9, 32, 15]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '3.8e-06', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# 200 [21, 92, 88, 130, 50, 69, 23, 61, 27]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '1.6e-06', '0.0e+00', '0.0e+00', '1.0e-05', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# ...
