# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def main():
    q1_learning()

# %%
def q1_learning():
    learning_stage_qlearn(N_episodes=1000)

# %%
from tictactoe import Q_System_QL, plot_cnt_trace_normal_order_detail

def learning_stage_qlearn(N_episodes=1000):
    my_Q_System = Q_System_QL()
    cnt_trace = my_Q_System.learning_qlearn(N_episodes=N_episodes, 
                                            print_cnt=N_episodes /5)
    my_Q_System.save()
    plot_cnt_trace_normal_order_detail(cnt_trace, title='Q-learning')

# %%
main()
# Out:
# 0 [0, 0, 1, 0, 1, 0, 0, 0, 1]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 200 [21, 97, 83, 119, 61, 64, 33, 55, 28]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['7.3e-09', '0.0e+00', '0.0e+00', '0.0e+00', '8.0e-07', '0.0e+00', '0.0e+00', '0.0e+00', '2.3e-05']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 400 [45, 204, 152, 237, 119, 134, 70, 103, 49]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['2.2e-08', '0.0e+00', '0.0e+00', '0.0e+00', '2.3e-06', '0.0e+00', '0.0e+00', '8.0e-07', '1.3e-04']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 600 [61, 312, 228, 361, 179, 203, 109, 158, 70]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['2.8e-08', '0.0e+00', '0.0e+00', '0.0e+00', '2.3e-06', '0.0e+00', '0.0e+00', '7.5e-07', '4.5e-04']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 800 [85, 427, 289, 489, 227, 284, 143, 205, 84]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['2.8e-08', '0.0e+00', '0.0e+00', '0.0e+00', '3.0e-06', '8.4e-08', '0.0e+00', '7.5e-07', '1.2e-03']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# (1000, 9) (1000, 1)
