# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def main():
    q1_learning()

# %%
def q1_learning():
    N_episodes = 1000
    epsilon = 0.2
    learning_stage_qlearn(N_episodes=N_episodes, 
                          epsilon=epsilon)

# %%
from tictactoe import Q_System_QL, plot_cnt_trace_normal_order_detail
import numpy as np

def learning_stage_qlearn(N_episodes=100, epsilon=0.4):
    my_Q_System = Q_System_QL()
    cnt_trace = my_Q_System.learning_qlearn(N_episodes=N_episodes, 
       epsilon=epsilon, print_cnt=N_episodes / 5)
    my_Q_System.save()
    plot_cnt_trace_normal_order_detail(cnt_trace, title='Q-learning')

# %%
main()
# Out:
# 0 [0, 0, 1, 0, 1, 0, 0, 0, 1]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 200 [14, 95, 92, 119, 68, 59, 36, 60, 32]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '1.6e-05', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '7.2e-09']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 400 [39, 189, 173, 236, 126, 122, 67, 114, 59]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['7.3e-09', '0.0e+00', '1.3e-04', '7.3e-09', '0.0e+00', '0.0e+00', '6.6e-11', '0.0e+00', '7.1e-09']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 600 [58, 290, 253, 340, 203, 180, 110, 160, 93]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['7.1e-09', '0.0e+00', '2.2e-04', '7.0e-09', '0.0e+00', '0.0e+00', '6.5e-11', '0.0e+00', '2.1e-08']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 800 [82, 395, 324, 452, 267, 247, 148, 205, 119]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['8.2e-07', '0.0e+00', '3.8e-04', '6.6e-09', '7.2e-09', '0.0e+00', '7.2e-09', '0.0e+00', '2.1e-08']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# (1000, 9) (1000, 1)
