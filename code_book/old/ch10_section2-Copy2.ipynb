# %%
# %load_ext autoreload
# %autoreload 2

# %%
def main():
    q1_learning()

# %%
def q1_learning():
    N_episodes = 1000
    epsilon = 0.2
    learning_stage_qlearn(N_episodes=N_episodes, 
                          epsilon=epsilon)

# %%
from tictactoe import Q_System_QL, plot_cnt_trace_normal_order_detail
import numpy as np

def learning_stage_qlearn(N_episodes=100, epsilon=0.4):
    
    N_Symbols = 3 # 0=empty, 1=plyaer1, 2=player2
    N_A = 9 # (0,0), (0,1), ..., (2,2)
    print_cnt = N_episodes / 5

    my_Q_System = Q_System_QL(N_A, N_Symbols)
    cnt_trace = my_Q_System.learning_qlearn(N_episodes=N_episodes, 
       epsilon=epsilon, print_cnt=print_cnt)
    my_Q_System.save()
    
    plot_cnt_trace_normal_order_detail(cnt_trace, title='Q-learning')

# %%
main()
# Out:
# 0 [0, 1, 0, 1, 0, 1, 0, 0, 0]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 200 [26, 98, 77, 106, 69, 60, 38, 46, 31]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '2.1e-05', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 400 [56, 180, 165, 214, 131, 113, 67, 101, 64]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '7.5e-05', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '7.2e-09']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 600 [75, 277, 249, 342, 184, 181, 96, 161, 88]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['2.1e-08', '0.0e+00', '2.7e-04', '0.0e+00', '7.9e-07', '0.0e+00', '0.0e+00', '0.0e+00', '7.1e-09']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 800 [96, 394, 311, 469, 236, 259, 135, 210, 101]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['2.1e-08', '0.0e+00', '8.0e-04', '0.0e+00', '1.6e-06', '0.0e+00', '0.0e+00', '0.0e+00', '6.9e-09']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# (1000, 9) (1000, 1)
