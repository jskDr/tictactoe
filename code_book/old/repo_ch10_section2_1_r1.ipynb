# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def main():
    q1_learning()

# %%
from tictactoe import learning_stage_qlearn

def q1_learning():
    N_episodes = 1000
    epsilon = 0.2
    learning_stage_qlearn(N_episodes=N_episodes, 
                          epsilon=epsilon, fig_flag=True)

# %%
main()
# Out:
# 0 [0, 1, 0, 1, 0, 1, 0, 0, 0]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 100 [9, 47, 45, 70, 22, 36, 11, 34, 11]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '8.5e-07', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 200 [17, 88, 96, 129, 55, 64, 24, 65, 31]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '7.3e-09', '0.0e+00', '0.0e+00', '0.0e+00', '4.8e-05', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 300 [35, 136, 130, 180, 86, 94, 42, 86, 44]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '7.1e-09', '7.2e-09', '7.3e-09', '0.0e+00', '0.0e+00', '8.6e-05', '8.1e-07']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 400 [45, 180, 176, 245, 111, 127, 53, 118, 58]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '1.4e-08', '7.2e-09', '7.2e-09', '0.0e+00', '0.0e+00', '1.1e-04', '8.1e-07']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 500 [55, 238, 208, 296, 150, 160, 78, 136, 72]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '8.2e-07', '7.1e-09', '7.1e-09', '0.0e+00', '0.0e+00', '1.9e-04', '8.0e-07']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 600 [61, 294, 246, 354, 186, 194, 100, 160, 86]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '8.2e-07', '7.0e-09', '7.0e-09', '0.0e+00', '0.0e+00', '4.3e-04', '8.0e-07']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 700 [66, 355, 280, 408, 227, 228, 127, 180, 100]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '8.1e-07', '7.0e-09', '6.9e-09', '0.0e+00', '0.0e+00', '8.9e-04', '7.9e-07']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 800 [81, 407, 313, 458, 262, 258, 149, 200, 113]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '1.6e-06', '1.4e-08', '6.9e-09', '0.0e+00', '0.0e+00', '1.3e-03', '2.4e-06']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 900 [89, 464, 348, 520, 292, 295, 169, 225, 123]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '1.6e-06', '2.1e-08', '6.9e-09', '0.0e+00', '0.0e+00', '1.8e-03', '2.4e-06']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# -------------------
# 1000 Last cnt:[98, 524, 378, 571, 331, 327, 197, 244, 134], Normalized last cnt:[0.098 0.524 0.378 0.571 0.331 0.327 0.197 0.244 0.134]
# (1000, 9) (1000, 1)
