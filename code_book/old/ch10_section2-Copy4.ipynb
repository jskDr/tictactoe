# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def main():
    q1_learning()

# %%
def q1_learning():
    N_episodes = 1000
    learning_stage_qlearn(N_episodes=N_episodes)

# %%
from tictactoe import Q_System_QL, plot_cnt_trace_normal_order_detail
import numpy as np

def learning_stage_qlearn(N_episodes=100):
    my_Q_System = Q_System_QL()
    cnt_trace = my_Q_System.learning_qlearn(N_episodes=N_episodes, 
                                            print_cnt=N_episodes / 5)
    my_Q_System.save()
    plot_cnt_trace_normal_order_detail(cnt_trace, title='Q-learning')

# %%
main()
# Out:
# 0 [0, 1, 0, 1, 0, 1, 0, 0, 0]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 200 [24, 99, 78, 115, 62, 65, 34, 50, 28]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '7.2e-09', '0.0e+00', '0.0e+00', '3.2e-05', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 400 [45, 198, 158, 252, 104, 140, 58, 112, 46]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['2.9e-08', '0.0e+00', '0.0e+00', '7.2e-09', '7.3e-09', '0.0e+00', '3.3e-04', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# ...
