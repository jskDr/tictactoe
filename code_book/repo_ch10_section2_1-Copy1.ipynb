# %%
# %load_ext autoreload
# %autoreload 2

# %%
def main():
    # 학습을 시작함.
    q1_learning()

# %%
import tictactoe

def q1_learning():
    # 강화학습의 전체 훈련 횟수 정의
    N_episodes = 1000
    # 탐험(Exploration) 빈도 정의
    epsilon = 0.2
    tictactoe.learning_stage_qlearn(N_episodes=N_episodes, 
        epsilon=epsilon, fig_flag=True, fig_mode='Basic')

# %%
main()
# Out:
# 0 [0, 1, 0, 1, 0, 1, 0, 0, 0]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 100 [14, 36, 51, 57, 30, 25, 11, 32, 19]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '7.1e-09', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '7.8e-06', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 200 [29, 80, 92, 116, 56, 56, 24, 60, 32]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '1.4e-08', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '3.9e-05', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# ...
