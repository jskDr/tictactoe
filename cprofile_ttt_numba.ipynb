# %%
# %load_ext autoreload
# %autoreload 2
import tictactoe
import cProfile

# %%
def run():
    epsilon_d = {'first value':0.4, 'second value':0.1, 'epsilon change episode':20}
    _= tictactoe.learning_stage_cnndqn_variable_epsilon(N_episodes=100, epsilon_d=epsilon_d, agent_type=2, fig_flag=True)

cProfile.run('run()')
#run()
# Out:
# WARNING:tensorflow:Layer cnn_agent_2 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer cnn_agent_3 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer cnn_agent is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
#
# Finished episode: # 0
# cnt:  [0, 1, 0, 1, 0, 1, 0, 0, 0]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# WARNING:tensorflow:Layer cnn_agent_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# Qsa[0][0,:] ['2.4e-02', '-3.4e-02', '1.7e-02', '-6.1e-02', '-5.5e-02', '-1.2e-01', '-5.1e-02', '-2.2e-01', '1.3e-02']
# Qsa[1][0,:] ['-5.7e-02', '-4.6e-02', '-1.3e-02', '-2.2e-02', '3.7e-02', '-7.0e-02', '-1.0e-01', '-6.9e-02', '-5.0e-02']
# Exproration: Epsilon= 0.4
#
# Finished episode: # 10
# cnt:  [5, 3, 3, 5, 1, 2, 1, 3, 0]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['4.8e-02', '-2.1e-02', '4.3e-02', '-2.1e-02', '1.8e-02', '-8.2e-02', '-4.4e-03', '-1.4e-01', '6.2e-02']
# Qsa[1][0,:] ['-5.7e-02', '-4.6e-02', '-1.3e-02', '-2.2e-02', '3.7e-02', '-7.0e-02', '-1.0e-01', '-6.9e-02', '-5.0e-02']
# Exproration: Epsilon= 0.4
#
# Finished episode: # 20
# cnt:  [11, 3, 7, 8, 2, 2, 1, 6, 1]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['6.4e-02', '-4.6e-03', '6.2e-02', '5.8e-03', '6.8e-02', '-5.8e-02', '2.3e-02', '-8.6e-02', '9.5e-02']
# Qsa[1][0,:] ['-5.7e-02', '-4.6e-02', '-1.3e-02', '-2.2e-02', '3.7e-02', '-7.0e-02', '-1.0e-01', '-6.9e-02', '-5.0e-02']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 30
# cnt:  [16, 3, 12, 13, 2, 2, 1, 11, 1]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['7.7e-02', '1.0e-02', '7.8e-02', '2.5e-02', '1.0e-01', '-4.3e-02', '3.8e-02', '-3.3e-02', '1.1e-01']
# Qsa[1][0,:] ['-5.7e-02', '-4.6e-02', '-1.3e-02', '-2.2e-02', '3.7e-02', '-7.0e-02', '-1.0e-01', '-6.9e-02', '-5.0e-02']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 40
# cnt:  [21, 3, 17, 18, 2, 2, 1, 16, 1]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['8.5e-02', '1.9e-02', '8.7e-02', '3.3e-02', '1.1e-01', '-3.9e-02', '4.8e-02', '-3.3e-04', '1.2e-01']
# Qsa[1][0,:] ['-5.7e-02', '-4.6e-02', '-1.3e-02', '-2.2e-02', '3.7e-02', '-7.0e-02', '-1.0e-01', '-6.9e-02', '-5.0e-02']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 50
# cnt:  [27, 3, 21, 22, 2, 2, 1, 20, 1]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['9.5e-02', '2.8e-02', '1.0e-01', '4.2e-02', '1.3e-01', '-3.3e-02', '5.7e-02', '2.6e-02', '1.3e-01']
# Qsa[1][0,:] ['-5.7e-02', '-4.6e-02', '-1.3e-02', '-2.2e-02', '3.7e-02', '-7.0e-02', '-1.0e-01', '-6.9e-02', '-5.0e-02']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 60
# cnt:  [31, 3, 27, 27, 3, 2, 1, 25, 2]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['1.0e-01', '3.4e-02', '1.1e-01', '4.8e-02', '1.3e-01', '-2.3e-02', '6.1e-02', '4.2e-02', '1.3e-01']
# Qsa[1][0,:] ['-5.7e-02', '-4.6e-02', '-1.3e-02', '-2.2e-02', '3.7e-02', '-7.0e-02', '-1.0e-01', '-6.9e-02', '-5.0e-02']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 70
# cnt:  [37, 3, 31, 31, 3, 2, 1, 29, 2]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['1.1e-01', '4.9e-02', '1.1e-01', '5.6e-02', '1.3e-01', '-1.6e-02', '7.3e-02', '6.3e-02', '1.4e-01']
# Qsa[1][0,:] ['-5.7e-02', '-4.6e-02', '-1.3e-02', '-2.2e-02', '3.7e-02', '-7.0e-02', '-1.0e-01', '-6.9e-02', '-5.0e-02']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 80
# cnt:  [42, 3, 36, 36, 3, 2, 1, 34, 2]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['1.2e-01', '6.0e-02', '1.2e-01', '6.1e-02', '1.4e-01', '-1.1e-02', '8.3e-02', '8.1e-02', '1.5e-01']
# Qsa[1][0,:] ['-5.7e-02', '-4.6e-02', '-1.3e-02', '-2.2e-02', '3.7e-02', '-7.0e-02', '-1.0e-01', '-6.9e-02', '-5.0e-02']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 90
# cnt:  [46, 4, 41, 42, 3, 3, 1, 39, 2]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['1.3e-01', '7.1e-02', '1.4e-01', '6.6e-02', '1.6e-01', '-9.0e-03', '1.0e-01', '9.8e-02', '1.7e-01']
# Qsa[1][0,:] ['-5.7e-02', '-4.6e-02', '-1.3e-02', '-2.2e-02', '3.7e-02', '-7.0e-02', '-1.0e-01', '-6.9e-02', '-5.0e-02']
# Exproration: Epsilon= 0.1
# -------------------
# 100 Last cnt:[51, 4, 45, 46, 3, 3, 1, 43, 2], Normalized last cnt:[0.51 0.04 0.45 0.46 0.03 0.03 0.01 0.43 0.02]
# (100, 9) (100, 1)
#          29288162 function calls (28301785 primitive calls) in 31.297 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       190    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(all)
#      2165    0.003    0.000    0.035    0.000 <__array_function__ internals>:2(amax)
#      1233    0.001    0.000    0.010    0.000 <__array_function__ internals>:2(amin)
#       908    0.001    0.000    0.011    0.000 <__array_function__ internals>:2(any)
#       400    0.000    0.000    0.004    0.000 <__array_function__ internals>:2(around)
#       300    0.000    0.000    0.006    0.000 <__array_function__ internals>:2(array_equal)
#        42    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(atleast_1d)
#        44    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(atleast_2d)
#        14    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_3d)
#       246    0.000    0.000    0.006    0.000 <__array_function__ internals>:2(broadcast_arrays)
#      1846    0.001    0.000    0.003    0.000 <__array_function__ internals>:2(can_cast)
#        84    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(clip)
#       250    0.000    0.000    0.004    0.000 <__array_function__ internals>:2(column_stack)
#       342    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(concatenate)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#       190    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(cumsum)
#        32    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diff)
#      1397    0.001    0.000    0.010    0.000 <__array_function__ internals>:2(dot)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(empty_like)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(full_like)
#        32    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(hstack)
#        46    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(isclose)
#        10    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(linspace)
#       178    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(ndim)
#        84    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(nonzero)
#     12632    0.019    0.000    0.363    0.000 <__array_function__ internals>:2(prod)
#        80    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(ptp)
#        56    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(result_type)
#       400    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(round_)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(sum)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(tile)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(unravel_index)
#        44    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(vstack)
#       601    0.001    0.000    0.003    0.000 <__array_function__ internals>:2(where)
# 5348/4960    0.005    0.000    0.049    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#        44    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:103(release)
#        41    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#        41    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:147(__enter__)
#        41    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:151(__exit__)
#        44    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#        44    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:176(cb)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:194(_lock_unlock_module)
#     72/29    0.000    0.000    0.041    0.001 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#       358    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#        15    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:269(_module_repr)
#        37    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:307(__init__)
#        37    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:311(__enter__)
#        37    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:318(__exit__)
#       148    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:321(<genexpr>)
#        35    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:35(_new_module)
#        38    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:369(__init__)
#        72    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:403(cached)
#      3666    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap>:416(parent)
#        52    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:424(has_location)
#        37    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:504(_init_module_attrs)
#        37    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap>:576(module_from_spec)
#        44    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:58(__init__)
#        15    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:593(_module_repr_from_spec)
#     37/29    0.000    0.000    0.038    0.001 <frozen importlib._bootstrap>:663(_load_unlocked)
#        38    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:719(find_spec)
#        44    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:78(acquire)
#        38    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:792(find_spec)
#       119    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:855(__enter__)
#       119    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:859(__exit__)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:873(_find_spec_legacy)
#        38    0.000    0.000    0.004    0.000 <frozen importlib._bootstrap>:882(_find_spec)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:929(_sanity_check)
#     38/29    0.000    0.000    0.041    0.001 <frozen importlib._bootstrap>:948(_find_and_load_unlocked)
#     41/32    0.000    0.000    0.041    0.001 <frozen importlib._bootstrap>:978(_find_and_load)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:994(_gcd_import)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1029(__init__)
#         2    0.000    0.000    0.002    0.001 <frozen importlib._bootstrap_external>:1040(create_module)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1048(exec_module)
#        60    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1203(_path_importer_cache)
#        38    0.000    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:1240(_get_spec)
#        38    0.000    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:1272(find_spec)
#        37    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1351(_get_spec)
#        58    0.001    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:1356(find_spec)
#        70    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:271(cache_from_source)
#        58    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:36(_relax_case)
#        37    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:369(_get_cached)
#        35    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:401(_check_name_wrapper)
#        35    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:438(_classify_pyc)
#        35    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:471(_validate_timestamp_pyc)
#       105    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:51(_r_long)
#        35    0.000    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:523(_compile_bytecode)
#       317    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:56(_path_join)
#        37    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:574(spec_from_file_location)
#       317    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:58(<listcomp>)
#        70    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:62(_path_split)
#        35    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:719(create_module)
#     35/28    0.000    0.000    0.035    0.001 <frozen importlib._bootstrap_external>:722(exec_module)
#       130    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:74(_path_stat)
#        35    0.000    0.000    0.009    0.000 <frozen importlib._bootstrap_external>:793(get_code)
#        37    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:84(_path_is_mode_type)
#        35    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:884(__init__)
#        35    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:909(get_filename)
#        35    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:914(get_data)
#        37    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:93(_path_isfile)
#        35    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:951(path_stats)
#         1    0.000    0.000   31.336   31.336 <ipython-input-2-51eca0e363b8>:1(run)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         6    0.000    0.000    0.000    0.000 <string>:1(__new__)
#         4    0.000    0.000    0.002    0.001 __init__.py:1002(flush)
#         4    0.000    0.000    0.003    0.001 __init__.py:1013(emit)
#         3    0.000    0.000    0.000    0.000 __init__.py:109(import_module)
#         4    0.000    0.000    0.000    0.000 __init__.py:117(getLevelName)
#         2    0.000    0.000    0.000    0.000 __init__.py:1216(getLogger)
#         1    0.000    0.000    0.000    0.000 __init__.py:1267(_fixupParents)
#         1    0.000    0.000    0.000    0.000 __init__.py:1317(safe_name)
#         1    0.000    0.000    0.000    0.000 __init__.py:1322(get_backend)
#         1    0.000    0.000    0.000    0.000 __init__.py:1336(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1337(safe_extra)
#         2    0.000    0.000    0.000    0.000 __init__.py:1342(is_interactive)
#      1819    0.001    0.000    0.001    0.000 __init__.py:1356(debug)
#       334    0.001    0.000    0.001    0.000 __init__.py:1373(is_math_text)
#         4    0.000    0.000    0.003    0.001 __init__.py:1380(warning)
#      1047    0.001    0.000    0.004    0.000 __init__.py:1382(_to_unmasked_float_array)
#        40    0.000    0.000    0.000    0.000 __init__.py:1393(_check_1d)
#       100    0.000    0.000    0.001    0.000 __init__.py:1406(_get_metadata_path)
#        79    0.000    0.000    0.002    0.000 __init__.py:1409(has_metadata)
#        21    0.000    0.000    0.002    0.000 __init__.py:1416(get_metadata)
#        34    0.000    0.000    0.000    0.000 __init__.py:143(__init__)
#        21    0.000    0.000    0.002    0.000 __init__.py:1431(get_metadata_lines)
#         4    0.000    0.000    0.000    0.000 __init__.py:1476(makeRecord)
#       100    0.000    0.000    0.001    0.000 __init__.py:1486(_fn)
#         4    0.000    0.000    0.003    0.001 __init__.py:1491(_log)
#       100    0.000    0.000    0.001    0.000 __init__.py:1492(_validate_resource_path)
#         4    0.000    0.000    0.003    0.001 __init__.py:1516(handle)
#         4    0.000    0.000    0.003    0.001 __init__.py:1570(callHandlers)
#         3    0.000    0.000    0.000    0.000 __init__.py:1600(getEffectiveLevel)
#        79    0.000    0.000    0.001    0.000 __init__.py:1603(_has)
#      1823    0.000    0.000    0.000    0.000 __init__.py:1614(isEnabledFor)
#        21    0.000    0.000    0.001    0.000 __init__.py:1615(_get)
#       246    0.000    0.000    0.000    0.000 __init__.py:1616(<lambda>)
#        71    0.000    0.000    0.000    0.000 __init__.py:163(connect)
#        88    0.000    0.000    0.000    0.000 __init__.py:1651(safe_first_element)
#       190    0.002    0.000    0.003    0.000 __init__.py:1673(normalize_kwargs)
#       190    0.000    0.000    0.000    0.000 __init__.py:1760(<listcomp>)
#       190    0.000    0.000    0.000    0.000 __init__.py:1765(<listcomp>)
#         2    0.000    0.000    0.000    0.000 __init__.py:180(_remove_proxy)
#         4    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#         1    0.000    0.000    0.000    0.000 __init__.py:187(_checkLevel)
#         6    0.000    0.000    0.000    0.000 __init__.py:1890(has_metadata)
#         1    0.000    0.000    0.000    0.000 __init__.py:190(disconnect)
#      1064    0.000    0.000    0.001    0.000 __init__.py:1906(_str_equal)
#       193    0.000    0.000    0.000    0.000 __init__.py:1916(_str_lower_equal)
#         2    0.000    0.000    0.000    0.000 __init__.py:1925(getLogger)
#        96    0.000    0.000    0.000    0.000 __init__.py:1947(method)
#      1758    0.002    0.000    0.004    0.000 __init__.py:2012(_setattr_cm)
#       879    0.001    0.000    0.001    0.000 __init__.py:2017(<listcomp>)
#        76    0.000    0.000    0.000    0.000 __init__.py:205(process)
#         2    0.000    0.000    0.000    0.000 __init__.py:2053(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:21(get_projection_class)
#         5    0.000    0.000    0.000    0.000 __init__.py:212(_acquireLock)
#      3674    0.002    0.000    0.004    0.000 __init__.py:2151(_check_in_list)
#         5    0.000    0.000    0.000    0.000 __init__.py:221(_releaseLock)
#         1    0.000    0.000    0.000    0.000 __init__.py:23(find_module)
#         4    0.000    0.000    0.000    0.000 __init__.py:232(__init__)
#  1192/415    0.001    0.000    0.005    0.000 __init__.py:2378(yield_lines)
#       132    0.000    0.000    0.000    0.000 __init__.py:2410(__init__)
#       132    0.000    0.000    0.003    0.000 __init__.py:2477(parse)
#       132    0.000    0.000    0.002    0.000 __init__.py:2497(_parse_extras)
#        32    0.000    0.000    0.004    0.000 __init__.py:2506(parse_group)
#        85    0.000    0.000    0.009    0.000 __init__.py:2519(parse_map)
#       249    0.000    0.000    0.004    0.000 __init__.py:2765(_get_metadata)
#       191    0.000    0.000    0.000    0.000 __init__.py:2812(__getattr__)
#         4    0.000    0.000    0.000    0.000 __init__.py:282(__init__)
#        85    0.000    0.000    0.009    0.000 __init__.py:2854(get_entry_map)
#         2    0.000    0.000    0.002    0.001 __init__.py:3075(parse_requirements)
#         1    0.000    0.000    0.002    0.002 __init__.py:3098(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:3108(<listcomp>)
#         1    0.000    0.000    0.002    0.002 __init__.py:3145(parse)
#         6    0.000    0.000    0.002    0.000 __init__.py:316(namedtuple)
#       181    0.000    0.000    0.005    0.000 __init__.py:3188(split_sections)
#         4    0.000    0.000    0.000    0.000 __init__.py:360(getMessage)
#        56    0.000    0.000    0.000    0.000 __init__.py:388(<genexpr>)
#         2    0.000    0.000    0.000    0.000 __init__.py:388(to_filehandle)
#      2982    0.004    0.000    0.007    0.000 __init__.py:403(_make)
#         4    0.000    0.000    0.000    0.000 __init__.py:418(usesTime)
#         4    0.000    0.000    0.000    0.000 __init__.py:421(format)
#         4    0.000    0.000    0.000    0.000 __init__.py:444(open_file_cm)
#        10    0.000    0.000    0.000    0.000 __init__.py:47(create_string_buffer)
#         2    0.000    0.000    0.000    0.000 __init__.py:48(get_projection_class)
#       134    0.000    0.000    0.000    0.000 __init__.py:497(cast)
#         8    0.000    0.000    0.000    0.000 __init__.py:501(string_at)
#        12    0.000    0.000    0.000    0.000 __init__.py:550(__init__)
#         6    0.000    0.000    0.000    0.000 __init__.py:570(__missing__)
#         4    0.000    0.000    0.000    0.000 __init__.py:573(usesTime)
#         4    0.000    0.000    0.000    0.000 __init__.py:579(formatMessage)
#         4    0.000    0.000    0.000    0.000 __init__.py:595(format)
#        12    0.000    0.000    0.000    0.000 __init__.py:619(update)
#        50    0.000    0.000    0.000    0.000 __init__.py:646(__setitem__)
#         1    0.000    0.000    0.000    0.000 __init__.py:646(iter_entry_points)
#         1    0.000    0.000    0.010    0.010 __init__.py:654(<genexpr>)
#         1    0.000    0.000    0.000    0.000 __init__.py:662(__init__)
#        86    0.000    0.000    0.000    0.000 __init__.py:668(__iter__)
#         5    0.000    0.000    0.000    0.000 __init__.py:690(push)
#         4    0.000    0.000    0.000    0.000 __init__.py:715(clear)
#         1    0.000    0.000    0.000    0.000 __init__.py:716(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:720(bubble)
#         8    0.000    0.000    0.000    0.000 __init__.py:736(filter)
#         5    0.000    0.000    0.000    0.000 __init__.py:76(__init__)
#     17745    0.009    0.000    0.012    0.000 __init__.py:810(__getitem__)
#         8    0.000    0.000    0.000    0.000 __init__.py:838(acquire)
#         8    0.000    0.000    0.000    0.000 __init__.py:845(release)
#        11    0.000    0.000    0.000    0.000 __init__.py:85(__hash__)
#         4    0.000    0.000    0.000    0.000 __init__.py:858(format)
#         4    0.000    0.000    0.003    0.001 __init__.py:881(handle)
#         2    0.000    0.000    0.000    0.000 __init__.py:913(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:914(<dictcomp>)
#       118    0.000    0.000    0.000    0.000 __init__.py:919(clean)
#       118    0.000    0.000    0.000    0.000 __init__.py:922(<listcomp>)
#       114    0.000    0.000    0.001    0.000 __init__.py:968(get_siblings)
#       114    0.000    0.000    0.000    0.000 __init__.py:972(<listcomp>)
#      5004    0.002    0.000    0.012    0.000 _asarray.py:16(asarray)
#      1324    0.001    0.000    0.002    0.000 _asarray.py:88(asanyarray)
#        10    0.000    0.000    0.017    0.002 _axes.py:1433(plot)
#         2    0.000    0.000    0.000    0.000 _axes.py:153(set_title)
#         2    0.000    0.000    0.000    0.000 _axes.py:223(set_xlabel)
#         2    0.000    0.000    0.000    0.000 _axes.py:256(set_ylabel)
#         2    0.000    0.000    0.011    0.005 _axes.py:299(legend)
#         4    0.000    0.000    0.000    0.000 _base.py:1133(_set_title_offset_trans)
#        16    0.000    0.000    0.000    0.000 _base.py:1219(get_aspect)
#         4    0.000    0.000    0.000    0.000 _base.py:1222(set_aspect)
#         4    0.000    0.000    0.000    0.000 _base.py:130(__init__)
#         4    0.000    0.000    0.000    0.000 _base.py:1304(set_adjustable)
#         4    0.000    0.000    0.000    0.000 _base.py:143(set_prop_cycle)
#        14    0.000    0.000    0.001    0.000 _base.py:1446(apply_aspect)
#        20    0.000    0.000    0.003    0.000 _base.py:154(__call__)
#        10    0.000    0.000    0.004    0.000 _base.py:1894(add_line)
#        10    0.000    0.000    0.002    0.000 _base.py:1920(_update_line_limits)
#        24    0.000    0.000    0.001    0.000 _base.py:2097(_process_unit_info)
#        48    0.000    0.000    0.001    0.000 _base.py:2100(_process_single_axis)
#        10    0.000    0.000    0.000    0.000 _base.py:2185(use_sticky_edges)
#        10    0.000    0.000    0.010    0.001 _base.py:2388(autoscale_view)
#        10    0.000    0.000    0.000    0.000 _base.py:241(_xy_from_xy)
#        10    0.000    0.000    0.000    0.000 _base.py:2415(<listcomp>)
#        10    0.000    0.000    0.000    0.000 _base.py:2416(<listcomp>)
#        10    0.000    0.000    0.000    0.000 _base.py:2417(<listcomp>)
#        20    0.001    0.000    0.010    0.000 _base.py:2425(handle_single_axis)
#        20    0.000    0.000    0.000    0.000 _base.py:2432(<listcomp>)
#        20    0.000    0.000    0.000    0.000 _base.py:2434(<listcomp>)
#        20    0.000    0.000    0.000    0.000 _base.py:2438(<listcomp>)
#        20    0.000    0.000    0.000    0.000 _base.py:2441(<listcomp>)
#        26    0.000    0.000    0.000    0.000 _base.py:2500(_get_axis_list)
#        12    0.000    0.000    0.019    0.002 _base.py:2503(_update_title_position)
#         4    0.000    0.000    0.228    0.057 _base.py:2573(draw)
#         2    0.000    0.000    0.000    0.000 _base.py:2708(set_axisbelow)
#         6    0.000    0.000    0.013    0.002 _base.py:2744(grid)
#        10    0.000    0.000    0.000    0.000 _base.py:281(_getdefaults)
#        20    0.000    0.000    0.000    0.000 _base.py:289(<genexpr>)
#         4    0.000    0.000    0.002    0.001 _base.py:2918(tick_params)
#        10    0.000    0.000    0.000    0.000 _base.py:299(_setdefaults)
#         2    0.000    0.000    0.000    0.000 _base.py:3027(set_axis_on)
#        10    0.000    0.000    0.000    0.000 _base.py:3050(xaxis_inverted)
#        10    0.000    0.000    0.000    0.000 _base.py:3064(get_xbound)
#        10    0.000    0.000    0.002    0.000 _base.py:308(_makeline)
#        10    0.000    0.000    0.001    0.000 _base.py:3080(set_xbound)
#        22    0.000    0.000    0.000    0.000 _base.py:3120(get_xlim)
#        48    0.000    0.000    0.001    0.000 _base.py:3143(_validate_converted_limits)
#        12    0.000    0.000    0.001    0.000 _base.py:3161(set_xlim)
#        36    0.000    0.000    0.000    0.000 _base.py:3288(get_xscale)
#        10    0.000    0.000    0.000    0.000 _base.py:3449(yaxis_inverted)
#        10    0.000    0.000    0.000    0.000 _base.py:3463(get_ybound)
#        10    0.000    0.000    0.001    0.000 _base.py:3479(set_ybound)
#        22    0.000    0.000    0.000    0.000 _base.py:3519(get_ylim)
#        12    0.000    0.000    0.001    0.000 _base.py:3542(set_ylim)
#        10    0.000    0.000    0.003    0.000 _base.py:363(_plot_args)
#        36    0.000    0.000    0.000    0.000 _base.py:3670(get_yscale)
#        30    0.000    0.000    0.000    0.000 _base.py:376(<genexpr>)
#         2    0.000    0.000    0.000    0.000 _base.py:3915(set_navigate)
#         2    0.000    0.000    0.000    0.000 _base.py:3931(set_navigate_mode)
#         2    0.000    0.000    0.031    0.015 _base.py:421(__init__)
#        24    0.000    0.000    0.000    0.000 _base.py:4248(get_children)
#         6    0.000    0.000    0.000    0.000 _base.py:4279(get_default_bbox_extra_artists)
#         6    0.000    0.000    0.000    0.000 _base.py:4299(<listcomp>)
#         4    0.001    0.000    0.099    0.025 _base.py:4302(get_tightbbox)
#         4    0.000    0.000    0.000    0.000 _base.py:4399(<listcomp>)
#        44    0.000    0.000    0.000    0.000 _base.py:576(get_window_extent)
#         2    0.000    0.000    0.003    0.002 _base.py:594(_init_axis)
#         2    0.000    0.000    0.000    0.000 _base.py:604(set_figure)
#         2    0.000    0.000    0.000    0.000 _base.py:624(_set_lim_and_transforms)
#   544/300    0.000    0.000    0.001    0.000 _base.py:660(get_xaxis_transform)
#        60    0.000    0.000    0.002    0.000 _base.py:684(get_xaxis_text1_transform)
#        60    0.000    0.000    0.001    0.000 _base.py:710(get_xaxis_text2_transform)
#   544/300    0.000    0.000    0.001    0.000 _base.py:736(get_yaxis_transform)
#        60    0.000    0.000    0.002    0.000 _base.py:760(get_yaxis_text1_transform)
#        60    0.000    0.000    0.001    0.000 _base.py:786(get_yaxis_text2_transform)
#         4    0.000    0.000    0.000    0.000 _base.py:812(_update_transScale)
#     12/10    0.000    0.000    0.000    0.000 _base.py:822(get_position)
#        14    0.000    0.000    0.001    0.000 _base.py:871(_set_position)
#         6    0.000    0.000    0.000    0.000 _base.py:898(set_axes_locator)
#        16    0.000    0.000    0.000    0.000 _base.py:909(get_axes_locator)
#        16    0.000    0.000    0.000    0.000 _base.py:915(_set_artist_props)
#         2    0.000    0.000    0.000    0.000 _base.py:925(_gen_axes_patch)
#         2    0.000    0.000    0.001    0.001 _base.py:942(_gen_axes_spines)
#        10    0.000    0.000    0.001    0.000 _base.py:957(<genexpr>)
#         2    0.000    0.000    0.023    0.012 _base.py:960(cla)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:252(__subclasshook__)
#         5    0.000    0.000    0.000    0.000 _collections_abc.py:271(__subclasshook__)
#       168    0.000    0.000    0.000    0.000 _collections_abc.py:302(__subclasshook__)
#         5    0.000    0.000    0.000    0.000 _collections_abc.py:349(__subclasshook__)
#        22    0.000    0.000    0.000    0.000 _collections_abc.py:367(__subclasshook__)
#       792    0.000    0.000    0.000    0.000 _collections_abc.py:392(__subclasshook__)
#     81705    0.081    0.000    0.299    0.000 _collections_abc.py:657(get)
#     81705    0.059    0.000    0.247    0.000 _collections_abc.py:664(__contains__)
#         8    0.000    0.000    0.000    0.000 _collections_abc.py:672(keys)
#     10385    0.013    0.000    0.019    0.000 _collections_abc.py:676(items)
#     10393    0.005    0.000    0.005    0.000 _collections_abc.py:698(__init__)
#         8    0.000    0.000    0.000    0.000 _collections_abc.py:701(__len__)
#        75    0.000    0.000    0.000    0.000 _collections_abc.py:719(__iter__)
#        15    0.000    0.000    0.000    0.000 _collections_abc.py:72(_check_methods)
#     52312    0.106    0.000    0.108    0.000 _collections_abc.py:742(__iter__)
#     25828    0.020    0.000    0.031    0.000 _collections_abc.py:879(__iter__)
#       688    0.003    0.000    0.007    0.000 _dtype.py:319(_name_get)
#        80    0.000    0.000    0.001    0.000 _methods.py:228(_ptp)
#       424    0.000    0.000    0.002    0.000 _methods.py:28(_amax)
#       184    0.000    0.000    0.001    0.000 _methods.py:32(_amin)
#        98    0.000    0.000    0.001    0.000 _methods.py:36(_sum)
#        10    0.000    0.000    0.000    0.000 _methods.py:44(_any)
#       368    0.000    0.000    0.002    0.000 _methods.py:47(_all)
#       168    0.001    0.000    0.002    0.000 _methods.py:63(_clip_dep_is_scalar_nan)
#       168    0.000    0.000    0.000    0.000 _methods.py:73(_clip_dep_is_byte_swapped)
#        84    0.001    0.000    0.001    0.000 _methods.py:78(_clip_dep_invoke_with_casting)
#        84    0.000    0.000    0.003    0.000 _methods.py:97(_clip)
#        23    0.000    0.000    0.000    0.000 _pylab_helpers.py:100(get_active)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:110(set_active)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:116(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:30(get_fig_manager)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:66(destroy_all)
#         2    0.000    0.000    0.000    0.000 _pylab_helpers.py:86(get_all_fig_managers)
#         2    0.000    0.000    0.000    0.000 _subplots.py:110(get_subplotspec)
#         2    0.000    0.000    0.001    0.000 _subplots.py:122(update_params)
#         2    0.000    0.000    0.031    0.016 _subplots.py:18(__init__)
#         1    0.000    0.000    0.000    0.000 _subplots.py:202(subplot_class_factory)
#         2    0.000    0.000    0.000    0.000 _subplots.py:217(<genexpr>)
#       122    0.000    0.000    0.000    0.000 _ufunc_config.py:139(geterr)
#       122    0.000    0.000    0.001    0.000 _ufunc_config.py:39(seterr)
#        61    0.000    0.000    0.000    0.000 _ufunc_config.py:437(__init__)
#        61    0.000    0.000    0.001    0.000 _ufunc_config.py:441(__enter__)
#        61    0.000    0.000    0.000    0.000 _ufunc_config.py:446(__exit__)
#       130    0.000    0.000    0.000    0.000 _utils.py:11(__init__)
#     14663    0.003    0.000    0.003    0.000 _utils.py:15(is_used)
#      7819    0.005    0.000    0.021    0.000 _utils.py:18(register)
#      7697    0.008    0.000    0.015    0.000 _utils.py:26(deduplicate)
# 22671/9140    0.014    0.000    0.091    0.000 _utils.py:46(__str__)
# 16234/16186    0.011    0.000    0.022    0.000 _utils.py:56(get_reference)
#       170    0.000    0.000    0.000    0.000 _utils.py:66(set_metadata)
#      6368    0.002    0.000    0.002    0.000 _utils.py:72(_stringify_metadata)
#       170    0.000    0.000    0.000    0.000 _utils.py:77(<listcomp>)
#     52228    0.020    0.000    0.066    0.000 abc.py:137(__instancecheck__)
# 4616/1988    0.001    0.000    0.008    0.000 abc.py:141(__subclasscheck__)
#         4    0.000    0.000    0.000    0.000 abstract.py:107(mangling_args)
#      1103    0.000    0.000    0.000    0.000 abstract.py:118(__repr__)
# 9601/7040    0.006    0.000    0.012    0.000 abstract.py:121(__hash__)
# 11322/10744    0.007    0.000    0.010    0.000 abstract.py:124(__eq__)
#       396    0.000    0.000    0.001    0.000 abstract.py:127(__ne__)
#       401    0.000    0.000    0.000    0.000 abstract.py:151(can_convert_from)
#       746    0.000    0.000    0.000    0.000 abstract.py:158(is_precise)
#         9    0.000    0.000    0.000    0.000 abstract.py:177(__call__)
#       752    0.000    0.000    0.000    0.000 abstract.py:22(_autoincr)
#         9    0.000    0.000    0.000    0.000 abstract.py:247(unify)
#       233    0.000    0.000    0.000    0.000 abstract.py:30(_on_type_disposal)
#        10    0.000    0.000    0.000    0.000 abstract.py:326(__init__)
#         4    0.000    0.000    0.000    0.000 abstract.py:337(iterator_type)
#         4    0.000    0.000    0.000    0.000 abstract.py:411(__init__)
#        37    0.000    0.000    0.000    0.000 abstract.py:421(_literal_init)
#        62    0.000    0.000    0.000    0.000 abstract.py:432(literal_value)
#       717    0.000    0.000    0.001    0.000 abstract.py:436(literal_type)
#      1176    0.001    0.000    0.006    0.000 abstract.py:51(_intern)
# 1176/1158    0.002    0.000    0.015    0.000 abstract.py:63(__call__)
#      1172    0.000    0.000    0.000    0.000 abstract.py:96(__init__)
#     15050    0.003    0.000    0.003    0.000 abstract.py:99(key)
#      1291    0.000    0.000    0.000    0.000 activations.py:280(linear)
#        32    0.000    0.000    0.000    0.000 activations.py:310(get)
#       100    0.001    0.000    0.027    0.000 adam.py:142(_create_slots)
#       100    0.004    0.000    0.111    0.001 adam.py:153(_prepare_local)
#       600    0.005    0.000    0.057    0.000 adam.py:184(_resource_apply_dense)
#         1    0.000    0.000    0.000    0.000 adam.py:48(__init__)
#        48    0.003    0.000    0.007    0.000 analysis.py:118(compute_dead_maps)
#       834    0.000    0.000    0.001    0.000 analysis.py:138(<genexpr>)
#       596    0.000    0.000    0.000    0.000 analysis.py:141(<genexpr>)
#       450    0.000    0.000    0.000    0.000 analysis.py:182(<genexpr>)
#        48    0.002    0.000    0.002    0.000 analysis.py:190(compute_live_variables)
#       150    0.000    0.000    0.000    0.000 analysis.py:200(fix_point_progress)
#        48    0.006    0.000    0.032    0.001 analysis.py:23(compute_use_defs)
#       120    0.002    0.000    0.037    0.000 analysis.py:235(compute_cfg_from_blocks)
#        16    0.000    0.000    0.007    0.000 analysis.py:287(dead_branch_prune)
#        16    0.000    0.000    0.000    0.000 analysis.py:299(find_branches)
#        16    0.000    0.000    0.000    0.000 analysis.py:349(Unknown)
#         8    0.000    0.000    0.000    0.000 analysis.py:352(resolve_input_arg_const)
#      1838    0.000    0.000    0.000    0.000 analysis.py:40(<genexpr>)
#        16    0.000    0.000    0.000    0.000 analysis.py:432(<listcomp>)
#         8    0.000    0.000    0.001    0.000 analysis.py:459(rewrite_semantic_constants)
#         2    0.000    0.000    0.000    0.000 analysis.py:476(rewrite_statement)
#       119    0.000    0.000    0.000    0.000 analysis.py:486(rewrite_array_ndim)
#       119    0.000    0.000    0.000    0.000 analysis.py:496(rewrite_tuple_len)
#         8    0.000    0.000    0.001    0.000 analysis.py:525(find_literally_calls)
#        48    0.000    0.000    0.009    0.000 analysis.py:60(compute_live_map)
#       414    0.001    0.000    0.002    0.000 analysis.py:66(fix_point_progress)
#      4332    0.001    0.000    0.001    0.000 analysis.py:69(<genexpr>)
#        96    0.000    0.000    0.009    0.000 analysis.py:71(fix_point)
#       138    0.003    0.000    0.003    0.000 analysis.py:81(def_reach)
#       180    0.003    0.000    0.004    0.000 analysis.py:91(liveness)
#         4    0.000    0.000    0.000    0.000 array_exprs.py:106(_get_array_operator)
#         4    0.000    0.000    0.000    0.000 array_exprs.py:116(_get_operands)
#         2    0.000    0.000    0.000    0.000 array_exprs.py:131(_translate_expr)
#         2    0.000    0.000    0.000    0.000 array_exprs.py:142(_handle_matches)
#         4    0.000    0.000    0.000    0.000 array_exprs.py:16(_is_ufunc)
#         4    0.000    0.000    0.000    0.000 array_exprs.py:179(_get_final_replacement)
#         2    0.000    0.000    0.000    0.000 array_exprs.py:189(apply)
#       9/2    0.000    0.000    0.000    0.000 array_exprs.py:267(_arr_expr_to_ast)
#         8    0.000    0.000    0.000    0.000 array_exprs.py:27(__init__)
#         4    0.000    0.000    0.000    0.000 array_exprs.py:310(_legalize_parameter_names)
#         2    0.000    0.000    0.142    0.071 array_exprs.py:334(_lower_array_expr)
#        69    0.000    0.000    0.001    0.000 array_exprs.py:34(match)
#         5    0.000    0.000    0.000    0.000 array_exprs.py:342(<lambda>)
#         2    0.000    0.000    0.000    0.000 array_exprs.py:345(<listcomp>)
#         2    0.000    0.000    0.000    0.000 array_exprs.py:353(<listcomp>)
#         7    0.000    0.000    0.000    0.000 array_exprs.py:378(<genexpr>)
#         2    0.000    0.000    0.000    0.000 array_exprs.py:399(ExprKernel)
#         2    0.000    0.000    0.002    0.001 array_exprs.py:400(generate)
#         2    0.000    0.000    0.000    0.000 array_exprs.py:402(<listcomp>)
#         2    0.000    0.000    0.000    0.000 array_exprs.py:409(<listcomp>)
#        14    0.000    0.000    0.000    0.000 array_exprs.py:67(_match_array_expr)
#         1    0.000    0.000    0.000    0.000 array_exprs.py:94(_has_explicit_output)
#       100    0.001    0.000    0.013    0.000 array_grad.py:607(_ReshapeGrad)
#      1997    0.004    0.000    0.019    0.000 array_ops.py:1255(_should_not_autopack)
#      6001    0.003    0.000    0.003    0.000 array_ops.py:1261(<genexpr>)
#      1997    0.002    0.000    0.021    0.000 array_ops.py:1265(_autopacking_conversion_function)
#       102    0.000    0.000    0.004    0.000 array_ops.py:136(fill)
#       312    0.001    0.000    0.025    0.000 array_ops.py:176(identity)
#     10353    0.040    0.000    1.344    0.000 array_ops.py:2304(_constant_if_small)
#      5189    0.031    0.000    0.758    0.000 array_ops.py:2314(zeros)
#       100    0.000    0.000    0.015    0.000 array_ops.py:2466(ones_like)
#       100    0.001    0.000    0.015    0.000 array_ops.py:2529(ones_like_impl)
#      5264    0.031    0.000    0.775    0.000 array_ops.py:2542(ones)
#       688    0.003    0.000    0.028    0.000 array_ops.py:3597(squeeze)
#       688    0.001    0.000    0.033    0.000 array_ops.py:3652(squeeze_v2)
#       800    0.001    0.000    0.039    0.000 array_ops.py:435(shape)
#       900    0.005    0.000    0.044    0.000 array_ops.py:461(shape_internal)
#       200    0.000    0.000    0.006    0.000 array_ops.py:489(shape_n)
#       100    0.000    0.000    0.008    0.000 array_ops.py:515(size)
#       100    0.001    0.000    0.008    0.000 array_ops.py:547(size_internal)
#       200    0.000    0.000    0.007    0.000 array_ops.py:586(rank)
#      1991    0.006    0.000    0.179    0.000 array_ops.py:59(reshape)
#       200    0.001    0.000    0.007    0.000 array_ops.py:620(rank_internal)
#         1    0.000    0.000    0.001    0.001 arraydecl.py:1(<module>)
#        15    0.000    0.000    0.000    0.000 arraydecl.py:107(keeps_contiguity)
#         9    0.000    0.000    0.000    0.000 arraydecl.py:114(check_contiguity)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:162(GetItemBuffer)
#         6    0.000    0.000    0.000    0.000 arraydecl.py:164(generic)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:171(SetItemBuffer)
#        15    0.000    0.000    0.001    0.000 arraydecl.py:173(generic)
#        21    0.000    0.000    0.001    0.000 arraydecl.py:19(get_array_index_type)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:236(ArrayAttribute)
#         4    0.000    0.000    0.000    0.000 arraydecl.py:246(resolve_shape)
#         2    0.000    0.000    0.000    0.000 arraydecl.py:339(resolve_item)
#         4    0.000    0.000    0.000    0.000 arraydecl.py:366(resolve_reshape)
#         8    0.000    0.000    0.000    0.000 arraydecl.py:368(sentry_shape_scalar)
#        12    0.000    0.000    0.000    0.000 arraydecl.py:402(<genexpr>)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:497(DTypeAttr)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:514(StaticGetItemArray)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:528(RecordAttribute)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:537(StaticGetItemRecord)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:549(StaticSetItemRecord)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:562(ArrayCTypesAttribute)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:570(ArrayFlagsAttribute)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:584(NestedArrayAttribute)
#         2    0.000    0.000    0.000    0.000 arraydecl.py:589(_expand_integer)
#         2    0.000    0.000    0.000    0.000 arraydecl.py:616(sum_expand)
#        11    0.000    0.000    0.000    0.000 arraydecl.py:715(install_array_method)
#         2    0.000    0.000    0.000    0.000 arraydecl.py:718(array_attribute_attachment)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:750(CmpOpEqArray)
#         2    0.000    0.000    0.000    0.000 arraymath.py:1008(_partition_factory)
#         2    0.000    0.000    0.000    0.000 arraymath.py:1049(_select_factory)
#         1    0.000    0.000    0.150    0.150 arraymath.py:160(array_sum)
#         2    0.000    0.000    0.000    0.000 arraymath.py:1994(np_interp_impl_complex_fp_inner_factory)
#         2    0.000    0.000    0.000    0.000 arraymath.py:2208(np_interp_impl_inner_factory)
#         1    0.000    0.000    0.010    0.010 arraymath.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 arraymath.py:31(_check_blas)
#         2    0.000    0.000    0.000    0.000 arraymath.py:3364(_searchsorted)
#         2    0.000    0.000    0.000    0.000 arraymath.py:3680(generate_xinfo)
#         1    0.000    0.000    0.000    0.000 arraymath.py:3736(_corr_conv_Mode)
#         4    0.000    0.000    0.000    0.000 arraymath.py:4018(window_generator)
#         4    0.000    0.000    0.000    0.000 arraymath.py:692(nan_min_max_factory)
#         2    0.000    0.000    0.000    0.000 arraymath.py:916(_compute_current_val_impl_gen)
#        10    0.000    0.000    0.001    0.000 arrayobj.py:1000(<genexpr>)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:1003(end_loops)
#         2    0.000    0.000    0.001    0.000 arrayobj.py:1071(offset_bounds_from_strides)
#         4    0.000    0.000    0.000    0.000 arrayobj.py:1113(compute_memory_extents)
#         2    0.000    0.000    0.001    0.000 arrayobj.py:1124(get_array_memory_extents)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:1135(extents_may_overlap)
#         2    0.000    0.000    0.002    0.001 arrayobj.py:1148(maybe_copy_source)
#         5    0.000    0.000    0.001    0.000 arrayobj.py:115(get_itemsize)
#         2    0.000    0.000    0.001    0.000 arrayobj.py:1179(src_getitem)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:1200(src_cleanup)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:1210(_bc_adjust_dimension)
#         5    0.000    0.000    0.000    0.000 arrayobj.py:123(load_item)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:1247(_bc_adjust_shape_strides)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:1259(<listcomp>)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:1261(<listcomp>)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:1262(<listcomp>)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:1263(<listcomp>)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:1265(<listcomp>)
#         2    0.000    0.000    0.005    0.002 arrayobj.py:1270(_broadcast_to_shape)
#         2    0.000    0.000    0.019    0.010 arrayobj.py:1292(fancy_setslice)
#         5    0.000    0.000    0.000    0.000 arrayobj.py:132(store_item)
#         6    0.000    0.000    0.000    0.000 arrayobj.py:1393(<genexpr>)
#        15    0.000    0.000    0.001    0.000 arrayobj.py:140(fix_integer_index)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:1417(vararg_to_tuple)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:1424(<listcomp>)
#         9    0.000    0.000    0.000    0.000 arrayobj.py:152(normalize_index)
# ...
#        50    0.000    0.000    0.002    0.000 {built-in method matplotlib._path.get_path_extents}
#        70    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.path_intersects_rectangle}
#        20    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.update_path_extents}
#         2    0.063    0.032    0.063    0.032 {built-in method matplotlib._png.write_png}
#         2    0.000    0.000    0.000    0.000 {built-in method numba._dynfunc.make_function}
#      2066    0.001    0.000    0.001    0.000 {built-in method numba.typeconv._typeconv.check_compatible}
#         5    0.000    0.000    0.000    0.000 {built-in method numba.typeconv._typeconv.get_pointer}
#       594    0.002    0.000    0.002    0.000 {built-in method numpy.arange}
#     13120    0.025    0.000    0.025    0.000 {built-in method numpy.array}
#        18    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.dragon4_positional}
# 23882/22724    0.041    0.000    0.439    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        32    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#       244    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         9    0.000    0.000    0.000    0.000 {built-in method numpy.promote_types}
#       122    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#      1007    0.002    0.000    0.002    0.000 {built-in method numpy.zeros}
#      1230    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#        68    0.003    0.000    0.003    0.000 {built-in method posix.getcwd}
#       269    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#       222    0.004    0.000    0.004    0.000 {built-in method posix.stat}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.urandom}
#        10    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#     10369    0.007    0.000    0.007    0.000 {built-in method sys.exc_info}
#        99    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#         6    0.000    0.000    0.000    0.000 {built-in method sys.intern}
#       960    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         4    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 {built-in method utcnow}
#        78    0.000    0.000    0.000    0.000 {function Config.__contains__ at 0x105fdda70}
#     19177    0.003    0.000    0.003    0.000 {function TargetRegistry.__getitem__ at 0x13f5914d0}
#     20738    0.119    0.000    0.119    0.000 {method 'ByteSize' of 'google.protobuf.pyext._message.CMessage' objects}
#     51845    0.114    0.000    0.114    0.000 {method 'CopyFrom' of 'google.protobuf.pyext._message.CMessage' objects}
#     82952    0.032    0.000    0.032    0.000 {method 'HasField' of 'google.protobuf.pyext._message.CMessage' objects}
#         1    0.000    0.000    0.000    0.000 {method 'MergeFrom' of 'google.protobuf.pyext._message.CMessage' objects}
#     31107    0.073    0.000    0.073    0.000 {method 'ParseFromString' of 'google.protobuf.pyext._message.CMessage' objects}
#     41477    0.097    0.000    0.097    0.000 {method 'SerializeToString' of 'google.protobuf.pyext._message.CMessage' objects}
#     31107    0.016    0.000    0.016    0.000 {method 'WhichOneof' of 'google.protobuf.pyext._message.CMessage' objects}
#        56    0.000    0.000    0.000    0.000 {method '__contains__' of 'frozenset' objects}
#         6    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        27    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#         1    0.000    0.000    0.000    0.000 {method '__subclasses__' of 'type' objects}
#    106250    0.022    0.000    0.022    0.000 {method '_datatype_enum' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#         2    0.000    0.000    0.000    0.000 {method '_insert' of '_dispatcher.Dispatcher' objects}
#         8    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         4    0.000    0.000    0.000    0.000 {method '_num_elements' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#      7761    0.032    0.000    0.032    0.000 {method '_numpy' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#       200    0.000    0.000    0.000    0.000 {method '_rank' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#     27617    0.019    0.000    0.019    0.000 {method '_shape_tuple' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#       189    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#     31438    0.018    0.000    0.018    0.000 {method 'acquire' of '_thread.lock' objects}
#     28898    0.006    0.000    0.009    0.000 {method 'add' of 'set' objects}
#        52    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.generic' objects}
#       316    0.000    0.000    0.002    0.000 {method 'all' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#       434    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#   1079578    0.115    0.000    0.115    0.000 {method 'append' of 'list' objects}
#       256    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        16    0.000    0.000    0.000    0.000 {method 'center' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#      1330    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#       332    0.000    0.000    0.000    0.000 {method 'clear' of 'frame' objects}
#       310    0.001    0.000    0.001    0.000 {method 'clear' of 'matplotlib.ft2font.FT2Font' objects}
#        84    0.000    0.000    0.004    0.000 {method 'clip' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedWriter' objects}
#         3    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#     10696    0.003    0.000    0.003    0.000 {method 'copy' of 'dict' objects}
#       722    0.000    0.000    0.000    0.000 {method 'copy' of 'list' objects}
#      9300    0.012    0.000    0.012    0.000 {method 'copy' of 'numpy.ndarray' objects}
#       410    0.000    0.000    0.000    0.000 {method 'copy' of 'set' objects}
#       668    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#       190    0.001    0.000    0.001    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#      1157    0.001    0.000    0.001    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#      1358    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#        80    0.002    0.000    0.002    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#        48    0.002    0.000    0.002    0.000 {method 'draw_markers' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#       114    0.009    0.000    0.012    0.000 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        80    0.002    0.000    0.002    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#     58113    0.029    0.000    0.029    0.000 {method 'encode' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'end' of 're.Match' objects}
#     63588    0.030    0.000    0.030    0.000 {method 'endswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'expandtabs' of 'str' objects}
#        66    0.000    0.000    0.000    0.000 {method 'extend' of 'collections.deque' objects}
#     31592    0.003    0.000    0.003    0.000 {method 'extend' of 'list' objects}
#        22    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#        58    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
# 36424/16394    0.027    0.000    0.098    0.000 {method 'format' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'from_address' of '_ctypes.PyCArrayType' objects}
#   1147927    0.150    0.000    0.155    0.000 {method 'get' of 'dict' objects}
#        13    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#        80    0.000    0.000    0.000    0.000 {method 'get_bitmap_offset' of 'matplotlib.ft2font.FT2Font' objects}
#       310    0.000    0.000    0.000    0.000 {method 'get_descent' of 'matplotlib.ft2font.FT2Font' objects}
#       230    0.000    0.000    0.000    0.000 {method 'get_width_height' of 'matplotlib.ft2font.FT2Font' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#         9    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#      5360    0.002    0.000    0.002    0.000 {method 'group' of 're.Match' objects}
#       132    0.000    0.000    0.000    0.000 {method 'groupdict' of 're.Match' objects}
#         4    0.000    0.000    0.000    0.000 {method 'groups' of 're.Match' objects}
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#        86    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#        12    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#      2288    0.001    0.000    0.001    0.000 {method 'index' of 'tuple' objects}
#         2    0.000    0.000    0.000    0.000 {method 'indices' of 'slice' objects}
#      7813    0.002    0.000    0.002    0.000 {method 'insert' of 'list' objects}
#       248    0.000    0.000    0.000    0.000 {method 'isalpha' of 'str' objects}
#       130    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#    124890    0.020    0.000    0.020    0.000 {method 'isidentifier' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#       194    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#     84436    0.016    0.000    0.016    0.000 {method 'items' of 'dict' objects}
#        31    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
# 15405/15358    0.005    0.000    0.011    0.000 {method 'join' of 'str' objects}
#       791    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#     17775    0.004    0.000    0.004    0.000 {method 'lower' of 'str' objects}
#     48837    0.061    0.000    0.061    0.000 {method 'match' of 're.Pattern' objects}
#       424    0.000    0.000    0.002    0.000 {method 'max' of 'numpy.ndarray' objects}
#       184    0.000    0.000    0.001    0.000 {method 'min' of 'numpy.ndarray' objects}
#        56    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#        84    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#        72    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.OrderedDict' objects}
#        14    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.deque' objects}
#    156074    0.037    0.000    0.037    0.000 {method 'pop' of 'dict' objects}
#     73914    0.031    0.000    0.031    0.000 {method 'pop' of 'list' objects}
#       259    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#       688    0.016    0.000    0.034    0.000 {method 'randint' of 'numpy.random.mtrand.RandomState' objects}
#       440    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#        21    0.000    0.000    0.000    0.000 {method 'read' of '_io.BufferedReader' objects}
#        35    0.000    0.000    0.000    0.000 {method 'read' of '_io.FileIO' objects}
#         3    0.001    0.000    0.001    0.000 {method 'readline' of '_io.BufferedReader' objects}
#         3    0.003    0.001    0.004    0.001 {method 'readlines' of '_io._IOBase' objects}
#     18312    0.235    0.000    0.250    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       189    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#     20744    0.006    0.000    0.006    0.000 {method 'release' of '_thread.lock' objects}
#       481    0.001    0.000    0.001    0.000 {method 'remove' of 'list' objects}
#       128    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'replace' of 'datetime.datetime' objects}
#       920    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#      2686    0.003    0.000    0.003    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#     10627    0.002    0.000    0.002    0.000 {method 'reverse' of 'list' objects}
#       126    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#       160    0.001    0.000    0.001    0.000 {method 'round' of 'numpy.generic' objects}
#       240    0.001    0.000    0.001    0.000 {method 'round' of 'numpy.ndarray' objects}
#      3938    0.001    0.000    0.001    0.000 {method 'rpartition' of 'str' objects}
#      7561    0.001    0.000    0.001    0.000 {method 'rstrip' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#       310    0.000    0.000    0.000    0.000 {method 'set_size' of 'matplotlib.ft2font.FT2Font' objects}
#       310    0.026    0.000    0.026    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
#         1    0.000    0.000    0.000    0.000 {method 'setdefault' of 'collections.OrderedDict' objects}
#      1343    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#       742    0.001    0.000    0.001    0.000 {method 'sort' of 'list' objects}
#       764    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#       327    0.001    0.000    0.001    0.000 {method 'splitlines' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#     72702    0.022    0.000    0.022    0.000 {method 'startswith' of 'str' objects}
#       629    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#      7950    0.048    0.000    0.080    0.000 {method 'sub' of 're.Pattern' objects}
#        98    0.000    0.000    0.001    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'translate' of 'bytearray' objects}
#         5    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HASH' objects}
#     11416    0.008    0.000    0.008    0.000 {method 'update' of 'dict' objects}
#      2968    0.001    0.000    0.001    0.000 {method 'update' of 'set' objects}
#        88    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#       131    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#     36726    0.006    0.000    0.006    0.000 {method 'values' of 'dict' objects}
#     18199    0.010    0.000    0.010    0.000 {method 'values' of 'mappingproxy' objects}
#       166    0.000    0.000    0.000    0.000 {method 'with_traceback' of 'BaseException' objects}
#         1    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
