# %%
# %load_ext autoreload
# %autoreload 2

#import numba
import tictactoe
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tictactoe.generate_action_list()
# Out:
# [[0],
#  [0, 1],
#  [0, 1, 2],
#  [0, 2],
#  [0, 2, 1],
#  [1],
#  [1, 0],
#  [1, 0, 2],
#  [1, 2],
#  [1, 2, 0],
#  [2],
#  [2, 0],
#  [2, 0, 1],
#  [2, 1],
#  [2, 1, 0]]

# %%
bellman = tictactoe.Bellman()
bellman.update([0,1,2,3],max_actions=4,disp_flag=False)
# Out:
# -----------------------
# S: [1 2 1 2 0 0 0 0 0]  with action:  4  in  [0, 1, 2, 3]
# Sa: [1 2 1 2 1 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 2 1 2 0 0 0 0 0]  with action:  5  in  [0, 1, 2, 3]
# Sa: [1 2 1 2 0 1 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 2 1 2 0 0 0 0 0]  with action:  6  in  [0, 1, 2, 3]
# Sa: [1 2 1 2 0 0 1 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 2 1 2 0 0 0 0 0]  with action:  7  in  [0, 1, 2, 3]
# Sa: [1 2 1 2 0 0 0 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 2 1 2 0 0 0 0 0]  with action:  8  in  [0, 1, 2, 3]
# Sa: [1 2 1 2 0 0 0 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0

# %%
bellman = tictactoe.Bellman()
bellman.update([0,3,1,4,8],max_actions=6,disp_flag=False)
# Out:
# -----------------------
# S: [1 1 2 2 2 0 0 0 1]  with action:  5  based on  [0, 3, 1, 4, 8, 2]
# Sa: [1 1 2 2 2 1 0 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 0 0 1]  with action:  6  based on  [0, 3, 1, 4, 8, 2]
# Sa: [1 1 2 2 2 0 1 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 0 0 1]  with action:  7  based on  [0, 3, 1, 4, 8, 2]
# Sa: [1 1 2 2 2 0 0 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Player 2 wins with Sa, action_list and done [1 1 0 2 2 2 0 0 1] [0, 3, 1, 4, 8, 5] True
# -----------------------
# S: [1 1 0 2 2 0 2 0 1]  with action:  2  based on  [0, 3, 1, 4, 8, 6]
# Sa: [1 1 1 2 2 0 2 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 2 0 1]  with action:  5  based on  [0, 3, 1, 4, 8, 6]
# Sa: [1 1 0 2 2 1 2 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 2 0 1]  with action:  7  based on  [0, 3, 1, 4, 8, 6]
# Sa: [1 1 0 2 2 0 2 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 2 1]  with action:  2  based on  [0, 3, 1, 4, 8, 7]
# Sa: [1 1 1 2 2 0 0 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 2 1]  with action:  5  based on  [0, 3, 1, 4, 8, 7]
# Sa: [1 1 0 2 2 1 0 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 2 1]  with action:  6  based on  [0, 3, 1, 4, 8, 7]
# Sa: [1 1 0 2 2 0 1 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0

# %%
bellman = tictactoe.Bellman()
bellman.update([0,3,1,4,8],max_actions=7,disp_flag=False)
# Out:
# -----------------------
# S: [1 1 2 2 2 0 0 0 1]  with action:  5  based on  [0, 3, 1, 4, 8, 2]
# Sa: [1 1 2 2 2 1 0 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Player 2 wins with Sa, action_list and done [1 1 2 2 2 1 2 0 1] [0, 3, 1, 4, 8, 2, 5, 6] True
# -----------------------
# S: [1 1 2 2 2 0 0 0 1]  with action:  6  based on  [0, 3, 1, 4, 8, 2]
# Sa: [1 1 2 2 2 0 1 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Player 2 wins with Sa, action_list and done [1 1 2 2 2 2 1 0 1] [0, 3, 1, 4, 8, 2, 6, 5] True
# -----------------------
# S: [1 1 2 2 2 0 0 0 1]  with action:  7  based on  [0, 3, 1, 4, 8, 2]
# Sa: [1 1 2 2 2 0 0 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Player 2 wins with Sa, action_list and done [1 1 2 2 2 2 0 1 1] [0, 3, 1, 4, 8, 2, 7, 5] True
# Player 2 wins with Sa, action_list and done [1 1 2 2 2 0 2 1 1] [0, 3, 1, 4, 8, 2, 7, 6] True
# Player 2 wins with Sa, action_list and done [1 1 0 2 2 2 0 0 1] [0, 3, 1, 4, 8, 5] True
# -----------------------
# S: [1 1 0 2 2 0 2 0 1]  with action:  2  based on  [0, 3, 1, 4, 8, 6]
# Sa: [1 1 1 2 2 0 2 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 2 0 1]  with action:  5  based on  [0, 3, 1, 4, 8, 6]
# Sa: [1 1 0 2 2 1 2 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Player 2 wins with Sa, action_list and done [1 1 2 2 2 1 2 0 1] [0, 3, 1, 4, 8, 6, 5, 2] True
# -----------------------
# S: [1 1 0 2 2 0 2 0 1]  with action:  7  based on  [0, 3, 1, 4, 8, 6]
# Sa: [1 1 0 2 2 0 2 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Player 2 wins with Sa, action_list and done [1 1 2 2 2 0 2 1 1] [0, 3, 1, 4, 8, 6, 7, 2] True
# Player 2 wins with Sa, action_list and done [1 1 0 2 2 2 2 1 1] [0, 3, 1, 4, 8, 6, 7, 5] True
# -----------------------
# S: [1 1 0 2 2 0 0 2 1]  with action:  2  based on  [0, 3, 1, 4, 8, 7]
# Sa: [1 1 1 2 2 0 0 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 2 1]  with action:  5  based on  [0, 3, 1, 4, 8, 7]
# Sa: [1 1 0 2 2 1 0 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 2 1]  with action:  6  based on  [0, 3, 1, 4, 8, 7]
# Sa: [1 1 0 2 2 0 1 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Player 2 wins with Sa, action_list and done [1 1 0 2 2 2 1 2 1] [0, 3, 1, 4, 8, 7, 6, 5] True

# %%
tictactoe.calc_reward_numba(tictactoe.MASK_L, np.array([1, 1, 2,  2, 2, 1,  2, 0, 1]))
# Out:
# 2

# %%
bellman = tictactoe.Bellman()
bellman.update([0,3,1],max_actions=6,disp_flag=False)
# Out:
# -----------------------
# S: [1 1 2 2 0 0 0 0 0]  with action:  4  based on  [0, 3, 1, 2]
# Sa: [1 1 2 2 1 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 2 0 0 0]  with action:  6  based on  [0, 3, 1, 2, 4, 5]
# Sa: [1 1 2 2 1 2 1 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 2 0 0 0]  with action:  7  based on  [0, 3, 1, 2, 4, 5]
# Sa: [1 1 2 2 1 2 0 1 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 2 0 0 0]  with action:  8  based on  [0, 3, 1, 2, 4, 5]
# Sa: [1 1 2 2 1 2 0 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 0 2 0 0]  with action:  5  based on  [0, 3, 1, 2, 4, 6]
# Sa: [1 1 2 2 1 1 2 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 0 2 0 0]  with action:  7  based on  [0, 3, 1, 2, 4, 6]
# Sa: [1 1 2 2 1 0 2 1 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 0 2 0 0]  with action:  8  based on  [0, 3, 1, 2, 4, 6]
# Sa: [1 1 2 2 1 0 2 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 0 0 2 0]  with action:  5  based on  [0, 3, 1, 2, 4, 7]
# Sa: [1 1 2 2 1 1 0 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 0 0 2 0]  with action:  6  based on  [0, 3, 1, 2, 4, 7]
# Sa: [1 1 2 2 1 0 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 0 0 2 0]  with action:  8  based on  [0, 3, 1, 2, 4, 7]
# Sa: [1 1 2 2 1 0 0 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 0 0 0 2]  with action:  5  based on  [0, 3, 1, 2, 4, 8]
# Sa: [1 1 2 2 1 1 0 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 0 0 0 2]  with action:  6  based on  [0, 3, 1, 2, 4, 8]
# Sa: [1 1 2 2 1 0 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 0 0 0 2]  with action:  7  based on  [0, 3, 1, 2, 4, 8]
# Sa: [1 1 2 2 1 0 0 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 0 0 0]  with action:  5  based on  [0, 3, 1, 2]
# Sa: [1 1 2 2 0 1 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 1 0 0 0]  with action:  6  based on  [0, 3, 1, 2, 5, 4]
# Sa: [1 1 2 2 2 1 1 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 1 0 0 0]  with action:  7  based on  [0, 3, 1, 2, 5, 4]
# Sa: [1 1 2 2 2 1 0 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 1 0 0 0]  with action:  8  based on  [0, 3, 1, 2, 5, 4]
# Sa: [1 1 2 2 2 1 0 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 1 2 0 0]  with action:  4  based on  [0, 3, 1, 2, 5, 6]
# Sa: [1 1 2 2 1 1 2 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 1 2 0 0]  with action:  7  based on  [0, 3, 1, 2, 5, 6]
# Sa: [1 1 2 2 0 1 2 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 1 2 0 0]  with action:  8  based on  [0, 3, 1, 2, 5, 6]
# Sa: [1 1 2 2 0 1 2 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 1 0 2 0]  with action:  4  based on  [0, 3, 1, 2, 5, 7]
# Sa: [1 1 2 2 1 1 0 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 1 0 2 0]  with action:  6  based on  [0, 3, 1, 2, 5, 7]
# Sa: [1 1 2 2 0 1 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 1 0 2 0]  with action:  8  based on  [0, 3, 1, 2, 5, 7]
# Sa: [1 1 2 2 0 1 0 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 1 0 0 2]  with action:  4  based on  [0, 3, 1, 2, 5, 8]
# Sa: [1 1 2 2 1 1 0 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 1 0 0 2]  with action:  6  based on  [0, 3, 1, 2, 5, 8]
# Sa: [1 1 2 2 0 1 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 1 0 0 2]  with action:  7  based on  [0, 3, 1, 2, 5, 8]
# Sa: [1 1 2 2 0 1 0 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 0 0 0]  with action:  6  based on  [0, 3, 1, 2]
# Sa: [1 1 2 2 0 0 1 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 1 0 0]  with action:  5  based on  [0, 3, 1, 2, 6, 4]
# Sa: [1 1 2 2 2 1 1 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 1 0 0]  with action:  7  based on  [0, 3, 1, 2, 6, 4]
# Sa: [1 1 2 2 2 0 1 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 1 0 0]  with action:  8  based on  [0, 3, 1, 2, 6, 4]
# Sa: [1 1 2 2 2 0 1 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 2 1 0 0]  with action:  4  based on  [0, 3, 1, 2, 6, 5]
# Sa: [1 1 2 2 1 2 1 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 2 1 0 0]  with action:  7  based on  [0, 3, 1, 2, 6, 5]
# Sa: [1 1 2 2 0 2 1 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 2 1 0 0]  with action:  8  based on  [0, 3, 1, 2, 6, 5]
# Sa: [1 1 2 2 0 2 1 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 1 2 0]  with action:  4  based on  [0, 3, 1, 2, 6, 7]
# Sa: [1 1 2 2 1 0 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 1 2 0]  with action:  5  based on  [0, 3, 1, 2, 6, 7]
# Sa: [1 1 2 2 0 1 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 1 2 0]  with action:  8  based on  [0, 3, 1, 2, 6, 7]
# Sa: [1 1 2 2 0 0 1 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 1 0 2]  with action:  4  based on  [0, 3, 1, 2, 6, 8]
# Sa: [1 1 2 2 1 0 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 1 0 2]  with action:  5  based on  [0, 3, 1, 2, 6, 8]
# Sa: [1 1 2 2 0 1 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 1 0 2]  with action:  7  based on  [0, 3, 1, 2, 6, 8]
# Sa: [1 1 2 2 0 0 1 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 0 0 0]  with action:  7  based on  [0, 3, 1, 2]
# Sa: [1 1 2 2 0 0 0 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 0 1 0]  with action:  5  based on  [0, 3, 1, 2, 7, 4]
# Sa: [1 1 2 2 2 1 0 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 0 1 0]  with action:  6  based on  [0, 3, 1, 2, 7, 4]
# Sa: [1 1 2 2 2 0 1 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 0 1 0]  with action:  8  based on  [0, 3, 1, 2, 7, 4]
# Sa: [1 1 2 2 2 0 0 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 2 0 1 0]  with action:  4  based on  [0, 3, 1, 2, 7, 5]
# Sa: [1 1 2 2 1 2 0 1 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 2 0 1 0]  with action:  6  based on  [0, 3, 1, 2, 7, 5]
# Sa: [1 1 2 2 0 2 1 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 2 0 1 0]  with action:  8  based on  [0, 3, 1, 2, 7, 5]
# Sa: [1 1 2 2 0 2 0 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 2 1 0]  with action:  4  based on  [0, 3, 1, 2, 7, 6]
# Sa: [1 1 2 2 1 0 2 1 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 2 1 0]  with action:  5  based on  [0, 3, 1, 2, 7, 6]
# Sa: [1 1 2 2 0 1 2 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 2 1 0]  with action:  8  based on  [0, 3, 1, 2, 7, 6]
# Sa: [1 1 2 2 0 0 2 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 0 1 2]  with action:  4  based on  [0, 3, 1, 2, 7, 8]
# Sa: [1 1 2 2 1 0 0 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 0 1 2]  with action:  5  based on  [0, 3, 1, 2, 7, 8]
# Sa: [1 1 2 2 0 1 0 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 0 1 2]  with action:  6  based on  [0, 3, 1, 2, 7, 8]
# Sa: [1 1 2 2 0 0 1 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 0 0 0]  with action:  8  based on  [0, 3, 1, 2]
# Sa: [1 1 2 2 0 0 0 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 0 0 1]  with action:  5  based on  [0, 3, 1, 2, 8, 4]
# Sa: [1 1 2 2 2 1 0 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 0 0 1]  with action:  6  based on  [0, 3, 1, 2, 8, 4]
# Sa: [1 1 2 2 2 0 1 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 0 0 1]  with action:  7  based on  [0, 3, 1, 2, 8, 4]
# Sa: [1 1 2 2 2 0 0 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 2 0 0 1]  with action:  4  based on  [0, 3, 1, 2, 8, 5]
# Sa: [1 1 2 2 1 2 0 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 2 0 0 1]  with action:  6  based on  [0, 3, 1, 2, 8, 5]
# Sa: [1 1 2 2 0 2 1 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 2 0 0 1]  with action:  7  based on  [0, 3, 1, 2, 8, 5]
# Sa: [1 1 2 2 0 2 0 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 2 0 1]  with action:  4  based on  [0, 3, 1, 2, 8, 6]
# Sa: [1 1 2 2 1 0 2 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 2 0 1]  with action:  5  based on  [0, 3, 1, 2, 8, 6]
# Sa: [1 1 2 2 0 1 2 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 2 0 1]  with action:  7  based on  [0, 3, 1, 2, 8, 6]
# Sa: [1 1 2 2 0 0 2 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 0 2 1]  with action:  4  based on  [0, 3, 1, 2, 8, 7]
# Sa: [1 1 2 2 1 0 0 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 0 2 1]  with action:  5  based on  [0, 3, 1, 2, 8, 7]
# Sa: [1 1 2 2 0 1 0 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 0 2 1]  with action:  6  based on  [0, 3, 1, 2, 8, 7]
# Sa: [1 1 2 2 0 0 1 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 0 0]  with action:  2  based on  [0, 3, 1, 4]
# Sa: [1 1 1 2 2 0 0 0 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 0 0]  with action:  5  based on  [0, 3, 1, 4]
# Sa: [1 1 0 2 2 1 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 1 0 0 0]  with action:  6  based on  [0, 3, 1, 4, 5, 2]
# Sa: [1 1 2 2 2 1 1 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 1 0 0 0]  with action:  7  based on  [0, 3, 1, 4, 5, 2]
# Sa: [1 1 2 2 2 1 0 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 1 0 0 0]  with action:  8  based on  [0, 3, 1, 4, 5, 2]
# Sa: [1 1 2 2 2 1 0 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 2 0 0]  with action:  2  based on  [0, 3, 1, 4, 5, 6]
# Sa: [1 1 1 2 2 1 2 0 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 2 0 0]  with action:  7  based on  [0, 3, 1, 4, 5, 6]
# Sa: [1 1 0 2 2 1 2 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 2 0 0]  with action:  8  based on  [0, 3, 1, 4, 5, 6]
# Sa: [1 1 0 2 2 1 2 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 0 2 0]  with action:  2  based on  [0, 3, 1, 4, 5, 7]
# Sa: [1 1 1 2 2 1 0 2 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 0 2 0]  with action:  6  based on  [0, 3, 1, 4, 5, 7]
# Sa: [1 1 0 2 2 1 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 0 2 0]  with action:  8  based on  [0, 3, 1, 4, 5, 7]
# Sa: [1 1 0 2 2 1 0 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 0 0 2]  with action:  2  based on  [0, 3, 1, 4, 5, 8]
# Sa: [1 1 1 2 2 1 0 0 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 0 0 2]  with action:  6  based on  [0, 3, 1, 4, 5, 8]
# Sa: [1 1 0 2 2 1 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 0 0 2]  with action:  7  based on  [0, 3, 1, 4, 5, 8]
# Sa: [1 1 0 2 2 1 0 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 0 0]  with action:  6  based on  [0, 3, 1, 4]
# Sa: [1 1 0 2 2 0 1 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 1 0 0]  with action:  5  based on  [0, 3, 1, 4, 6, 2]
# Sa: [1 1 2 2 2 1 1 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 1 0 0]  with action:  7  based on  [0, 3, 1, 4, 6, 2]
# Sa: [1 1 2 2 2 0 1 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 1 0 0]  with action:  8  based on  [0, 3, 1, 4, 6, 2]
# Sa: [1 1 2 2 2 0 1 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Player 2 wins with Sa, action_list and done [1 1 0 2 2 2 1 0 0] [0, 3, 1, 4, 6, 5] True
# -----------------------
# S: [1 1 0 2 2 0 1 2 0]  with action:  2  based on  [0, 3, 1, 4, 6, 7]
# Sa: [1 1 1 2 2 0 1 2 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 1 2 0]  with action:  5  based on  [0, 3, 1, 4, 6, 7]
# Sa: [1 1 0 2 2 1 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 1 2 0]  with action:  8  based on  [0, 3, 1, 4, 6, 7]
# Sa: [1 1 0 2 2 0 1 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 1 0 2]  with action:  2  based on  [0, 3, 1, 4, 6, 8]
# Sa: [1 1 1 2 2 0 1 0 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 1 0 2]  with action:  5  based on  [0, 3, 1, 4, 6, 8]
# Sa: [1 1 0 2 2 1 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 1 0 2]  with action:  7  based on  [0, 3, 1, 4, 6, 8]
# Sa: [1 1 0 2 2 0 1 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 0 0]  with action:  7  based on  [0, 3, 1, 4]
# Sa: [1 1 0 2 2 0 0 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 0 1 0]  with action:  5  based on  [0, 3, 1, 4, 7, 2]
# Sa: [1 1 2 2 2 1 0 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 0 1 0]  with action:  6  based on  [0, 3, 1, 4, 7, 2]
# Sa: [1 1 2 2 2 0 1 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 0 1 0]  with action:  8  based on  [0, 3, 1, 4, 7, 2]
# Sa: [1 1 2 2 2 0 0 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Player 2 wins with Sa, action_list and done [1 1 0 2 2 2 0 1 0] [0, 3, 1, 4, 7, 5] True
# -----------------------
# S: [1 1 0 2 2 0 2 1 0]  with action:  2  based on  [0, 3, 1, 4, 7, 6]
# Sa: [1 1 1 2 2 0 2 1 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 2 1 0]  with action:  5  based on  [0, 3, 1, 4, 7, 6]
# Sa: [1 1 0 2 2 1 2 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 2 1 0]  with action:  8  based on  [0, 3, 1, 4, 7, 6]
# Sa: [1 1 0 2 2 0 2 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 1 2]  with action:  2  based on  [0, 3, 1, 4, 7, 8]
# Sa: [1 1 1 2 2 0 0 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 1 2]  with action:  5  based on  [0, 3, 1, 4, 7, 8]
# Sa: [1 1 0 2 2 1 0 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 1 2]  with action:  6  based on  [0, 3, 1, 4, 7, 8]
# Sa: [1 1 0 2 2 0 1 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 0 0]  with action:  8  based on  [0, 3, 1, 4]
# Sa: [1 1 0 2 2 0 0 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 0 0 1]  with action:  5  based on  [0, 3, 1, 4, 8, 2]
# Sa: [1 1 2 2 2 1 0 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 0 0 1]  with action:  6  based on  [0, 3, 1, 4, 8, 2]
# Sa: [1 1 2 2 2 0 1 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 2 0 0 0 1]  with action:  7  based on  [0, 3, 1, 4, 8, 2]
# Sa: [1 1 2 2 2 0 0 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Player 2 wins with Sa, action_list and done [1 1 0 2 2 2 0 0 1] [0, 3, 1, 4, 8, 5] True
# -----------------------
# S: [1 1 0 2 2 0 2 0 1]  with action:  2  based on  [0, 3, 1, 4, 8, 6]
# Sa: [1 1 1 2 2 0 2 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 2 0 1]  with action:  5  based on  [0, 3, 1, 4, 8, 6]
# Sa: [1 1 0 2 2 1 2 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 2 0 1]  with action:  7  based on  [0, 3, 1, 4, 8, 6]
# Sa: [1 1 0 2 2 0 2 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 2 1]  with action:  2  based on  [0, 3, 1, 4, 8, 7]
# Sa: [1 1 1 2 2 0 0 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 2 1]  with action:  5  based on  [0, 3, 1, 4, 8, 7]
# Sa: [1 1 0 2 2 1 0 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 2 1]  with action:  6  based on  [0, 3, 1, 4, 8, 7]
# Sa: [1 1 0 2 2 0 1 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 0 0]  with action:  2  based on  [0, 3, 1, 5]
# Sa: [1 1 1 2 0 2 0 0 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 0 0]  with action:  4  based on  [0, 3, 1, 5]
# Sa: [1 1 0 2 1 2 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 2.0
# -----------------------
# S: [1 1 2 2 1 2 0 0 0]  with action:  6  based on  [0, 3, 1, 5, 4, 2]
# Sa: [1 1 2 2 1 2 1 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 2 0 0 0]  with action:  7  based on  [0, 3, 1, 5, 4, 2]
# Sa: [1 1 2 2 1 2 0 1 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 2 0 0 0]  with action:  8  based on  [0, 3, 1, 5, 4, 2]
# Sa: [1 1 2 2 1 2 0 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 2 0 0]  with action:  2  based on  [0, 3, 1, 5, 4, 6]
# Sa: [1 1 1 2 1 2 2 0 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 2 0 0]  with action:  7  based on  [0, 3, 1, 5, 4, 6]
# Sa: [1 1 0 2 1 2 2 1 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 2 0 0]  with action:  8  based on  [0, 3, 1, 5, 4, 6]
# Sa: [1 1 0 2 1 2 2 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 0 2 0]  with action:  2  based on  [0, 3, 1, 5, 4, 7]
# Sa: [1 1 1 2 1 2 0 2 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 0 2 0]  with action:  6  based on  [0, 3, 1, 5, 4, 7]
# Sa: [1 1 0 2 1 2 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 0 2 0]  with action:  8  based on  [0, 3, 1, 5, 4, 7]
# Sa: [1 1 0 2 1 2 0 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 0 0 2]  with action:  2  based on  [0, 3, 1, 5, 4, 8]
# Sa: [1 1 1 2 1 2 0 0 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 0 0 2]  with action:  6  based on  [0, 3, 1, 5, 4, 8]
# Sa: [1 1 0 2 1 2 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 0 0 2]  with action:  7  based on  [0, 3, 1, 5, 4, 8]
# Sa: [1 1 0 2 1 2 0 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 0 0]  with action:  6  based on  [0, 3, 1, 5]
# Sa: [1 1 0 2 0 2 1 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 2 1 0 0]  with action:  4  based on  [0, 3, 1, 5, 6, 2]
# Sa: [1 1 2 2 1 2 1 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 2 1 0 0]  with action:  7  based on  [0, 3, 1, 5, 6, 2]
# Sa: [1 1 2 2 0 2 1 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 2 1 0 0]  with action:  8  based on  [0, 3, 1, 5, 6, 2]
# Sa: [1 1 2 2 0 2 1 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Player 2 wins with Sa, action_list and done [1 1 0 2 2 2 1 0 0] [0, 3, 1, 5, 6, 4] True
# -----------------------
# S: [1 1 0 2 0 2 1 2 0]  with action:  2  based on  [0, 3, 1, 5, 6, 7]
# Sa: [1 1 1 2 0 2 1 2 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 1 2 0]  with action:  4  based on  [0, 3, 1, 5, 6, 7]
# Sa: [1 1 0 2 1 2 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 1 2 0]  with action:  8  based on  [0, 3, 1, 5, 6, 7]
# Sa: [1 1 0 2 0 2 1 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 1 0 2]  with action:  2  based on  [0, 3, 1, 5, 6, 8]
# Sa: [1 1 1 2 0 2 1 0 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 1 0 2]  with action:  4  based on  [0, 3, 1, 5, 6, 8]
# Sa: [1 1 0 2 1 2 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 1 0 2]  with action:  7  based on  [0, 3, 1, 5, 6, 8]
# Sa: [1 1 0 2 0 2 1 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 0 0]  with action:  7  based on  [0, 3, 1, 5]
# Sa: [1 1 0 2 0 2 0 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 1.0
# -----------------------
# S: [1 1 2 2 0 2 0 1 0]  with action:  4  based on  [0, 3, 1, 5, 7, 2]
# Sa: [1 1 2 2 1 2 0 1 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 2 0 1 0]  with action:  6  based on  [0, 3, 1, 5, 7, 2]
# Sa: [1 1 2 2 0 2 1 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 2 0 1 0]  with action:  8  based on  [0, 3, 1, 5, 7, 2]
# Sa: [1 1 2 2 0 2 0 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Player 2 wins with Sa, action_list and done [1 1 0 2 2 2 0 1 0] [0, 3, 1, 5, 7, 4] True
# -----------------------
# S: [1 1 0 2 0 2 2 1 0]  with action:  2  based on  [0, 3, 1, 5, 7, 6]
# Sa: [1 1 1 2 0 2 2 1 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 2 1 0]  with action:  4  based on  [0, 3, 1, 5, 7, 6]
# Sa: [1 1 0 2 1 2 2 1 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 2 1 0]  with action:  8  based on  [0, 3, 1, 5, 7, 6]
# Sa: [1 1 0 2 0 2 2 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 1 2]  with action:  2  based on  [0, 3, 1, 5, 7, 8]
# Sa: [1 1 1 2 0 2 0 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 1 2]  with action:  4  based on  [0, 3, 1, 5, 7, 8]
# Sa: [1 1 0 2 1 2 0 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 1 2]  with action:  6  based on  [0, 3, 1, 5, 7, 8]
# Sa: [1 1 0 2 0 2 1 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 0 0]  with action:  8  based on  [0, 3, 1, 5]
# Sa: [1 1 0 2 0 2 0 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 1.0
# -----------------------
# S: [1 1 2 2 0 2 0 0 1]  with action:  4  based on  [0, 3, 1, 5, 8, 2]
# Sa: [1 1 2 2 1 2 0 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 2 0 0 1]  with action:  6  based on  [0, 3, 1, 5, 8, 2]
# Sa: [1 1 2 2 0 2 1 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 2 0 0 1]  with action:  7  based on  [0, 3, 1, 5, 8, 2]
# Sa: [1 1 2 2 0 2 0 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Player 2 wins with Sa, action_list and done [1 1 0 2 2 2 0 0 1] [0, 3, 1, 5, 8, 4] True
# -----------------------
# S: [1 1 0 2 0 2 2 0 1]  with action:  2  based on  [0, 3, 1, 5, 8, 6]
# Sa: [1 1 1 2 0 2 2 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 2 0 1]  with action:  4  based on  [0, 3, 1, 5, 8, 6]
# Sa: [1 1 0 2 1 2 2 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 2 0 1]  with action:  7  based on  [0, 3, 1, 5, 8, 6]
# Sa: [1 1 0 2 0 2 2 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 2 1]  with action:  2  based on  [0, 3, 1, 5, 8, 7]
# Sa: [1 1 1 2 0 2 0 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 2 1]  with action:  4  based on  [0, 3, 1, 5, 8, 7]
# Sa: [1 1 0 2 1 2 0 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 2 1]  with action:  6  based on  [0, 3, 1, 5, 8, 7]
# Sa: [1 1 0 2 0 2 1 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 0 0]  with action:  2  based on  [0, 3, 1, 6]
# Sa: [1 1 1 2 0 0 2 0 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 0 0]  with action:  4  based on  [0, 3, 1, 6]
# Sa: [1 1 0 2 1 0 2 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 5.0
# -----------------------
# S: [1 1 2 2 1 0 2 0 0]  with action:  5  based on  [0, 3, 1, 6, 4, 2]
# Sa: [1 1 2 2 1 1 2 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 0 2 0 0]  with action:  7  based on  [0, 3, 1, 6, 4, 2]
# Sa: [1 1 2 2 1 0 2 1 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 0 2 0 0]  with action:  8  based on  [0, 3, 1, 6, 4, 2]
# Sa: [1 1 2 2 1 0 2 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 2 0 0]  with action:  2  based on  [0, 3, 1, 6, 4, 5]
# Sa: [1 1 1 2 1 2 2 0 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 2 0 0]  with action:  7  based on  [0, 3, 1, 6, 4, 5]
# Sa: [1 1 0 2 1 2 2 1 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 2 0 0]  with action:  8  based on  [0, 3, 1, 6, 4, 5]
# Sa: [1 1 0 2 1 2 2 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 2 2 0]  with action:  2  based on  [0, 3, 1, 6, 4, 7]
# Sa: [1 1 1 2 1 0 2 2 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 2 2 0]  with action:  5  based on  [0, 3, 1, 6, 4, 7]
# Sa: [1 1 0 2 1 1 2 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 2 2 0]  with action:  8  based on  [0, 3, 1, 6, 4, 7]
# Sa: [1 1 0 2 1 0 2 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 2 0 2]  with action:  2  based on  [0, 3, 1, 6, 4, 8]
# Sa: [1 1 1 2 1 0 2 0 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 2 0 2]  with action:  5  based on  [0, 3, 1, 6, 4, 8]
# Sa: [1 1 0 2 1 1 2 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 2 0 2]  with action:  7  based on  [0, 3, 1, 6, 4, 8]
# Sa: [1 1 0 2 1 0 2 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 0 0]  with action:  5  based on  [0, 3, 1, 6]
# Sa: [1 1 0 2 0 1 2 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 1.0
# -----------------------
# S: [1 1 2 2 0 1 2 0 0]  with action:  4  based on  [0, 3, 1, 6, 5, 2]
# Sa: [1 1 2 2 1 1 2 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 1 2 0 0]  with action:  7  based on  [0, 3, 1, 6, 5, 2]
# Sa: [1 1 2 2 0 1 2 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 1 2 0 0]  with action:  8  based on  [0, 3, 1, 6, 5, 2]
# Sa: [1 1 2 2 0 1 2 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 2 0 0]  with action:  2  based on  [0, 3, 1, 6, 5, 4]
# Sa: [1 1 1 2 2 1 2 0 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 2 0 0]  with action:  7  based on  [0, 3, 1, 6, 5, 4]
# Sa: [1 1 0 2 2 1 2 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 2 0 0]  with action:  8  based on  [0, 3, 1, 6, 5, 4]
# Sa: [1 1 0 2 2 1 2 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 2 2 0]  with action:  2  based on  [0, 3, 1, 6, 5, 7]
# Sa: [1 1 1 2 0 1 2 2 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 2 2 0]  with action:  4  based on  [0, 3, 1, 6, 5, 7]
# Sa: [1 1 0 2 1 1 2 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 2 2 0]  with action:  8  based on  [0, 3, 1, 6, 5, 7]
# Sa: [1 1 0 2 0 1 2 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 2 0 2]  with action:  2  based on  [0, 3, 1, 6, 5, 8]
# Sa: [1 1 1 2 0 1 2 0 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 2 0 2]  with action:  4  based on  [0, 3, 1, 6, 5, 8]
# Sa: [1 1 0 2 1 1 2 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 2 0 2]  with action:  7  based on  [0, 3, 1, 6, 5, 8]
# Sa: [1 1 0 2 0 1 2 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 0 0]  with action:  7  based on  [0, 3, 1, 6]
# Sa: [1 1 0 2 0 0 2 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 4.0
# -----------------------
# S: [1 1 2 2 0 0 2 1 0]  with action:  4  based on  [0, 3, 1, 6, 7, 2]
# Sa: [1 1 2 2 1 0 2 1 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 2 1 0]  with action:  5  based on  [0, 3, 1, 6, 7, 2]
# Sa: [1 1 2 2 0 1 2 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 2 1 0]  with action:  8  based on  [0, 3, 1, 6, 7, 2]
# Sa: [1 1 2 2 0 0 2 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 2 1 0]  with action:  2  based on  [0, 3, 1, 6, 7, 4]
# Sa: [1 1 1 2 2 0 2 1 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 2 1 0]  with action:  5  based on  [0, 3, 1, 6, 7, 4]
# Sa: [1 1 0 2 2 1 2 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 2 1 0]  with action:  8  based on  [0, 3, 1, 6, 7, 4]
# Sa: [1 1 0 2 2 0 2 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 2 1 0]  with action:  2  based on  [0, 3, 1, 6, 7, 5]
# Sa: [1 1 1 2 0 2 2 1 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 2 1 0]  with action:  4  based on  [0, 3, 1, 6, 7, 5]
# Sa: [1 1 0 2 1 2 2 1 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 2 1 0]  with action:  8  based on  [0, 3, 1, 6, 7, 5]
# Sa: [1 1 0 2 0 2 2 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 1 2]  with action:  2  based on  [0, 3, 1, 6, 7, 8]
# Sa: [1 1 1 2 0 0 2 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 1 2]  with action:  4  based on  [0, 3, 1, 6, 7, 8]
# Sa: [1 1 0 2 1 0 2 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 1 2]  with action:  5  based on  [0, 3, 1, 6, 7, 8]
# Sa: [1 1 0 2 0 1 2 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 0 0]  with action:  8  based on  [0, 3, 1, 6]
# Sa: [1 1 0 2 0 0 2 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 4.0
# -----------------------
# S: [1 1 2 2 0 0 2 0 1]  with action:  4  based on  [0, 3, 1, 6, 8, 2]
# Sa: [1 1 2 2 1 0 2 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 2 0 1]  with action:  5  based on  [0, 3, 1, 6, 8, 2]
# Sa: [1 1 2 2 0 1 2 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 2 0 1]  with action:  7  based on  [0, 3, 1, 6, 8, 2]
# Sa: [1 1 2 2 0 0 2 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 2 0 1]  with action:  2  based on  [0, 3, 1, 6, 8, 4]
# Sa: [1 1 1 2 2 0 2 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 2 0 1]  with action:  5  based on  [0, 3, 1, 6, 8, 4]
# Sa: [1 1 0 2 2 1 2 0 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 2 0 1]  with action:  7  based on  [0, 3, 1, 6, 8, 4]
# Sa: [1 1 0 2 2 0 2 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 2 0 1]  with action:  2  based on  [0, 3, 1, 6, 8, 5]
# Sa: [1 1 1 2 0 2 2 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 2 0 1]  with action:  4  based on  [0, 3, 1, 6, 8, 5]
# Sa: [1 1 0 2 1 2 2 0 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 2 0 1]  with action:  7  based on  [0, 3, 1, 6, 8, 5]
# Sa: [1 1 0 2 0 2 2 1 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 2 1]  with action:  2  based on  [0, 3, 1, 6, 8, 7]
# Sa: [1 1 1 2 0 0 2 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 2 1]  with action:  4  based on  [0, 3, 1, 6, 8, 7]
# Sa: [1 1 0 2 1 0 2 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 2 1]  with action:  5  based on  [0, 3, 1, 6, 8, 7]
# Sa: [1 1 0 2 0 1 2 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 0 2 0]  with action:  2  based on  [0, 3, 1, 7]
# Sa: [1 1 1 2 0 0 0 2 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 0 2 0]  with action:  4  based on  [0, 3, 1, 7]
# Sa: [1 1 0 2 1 0 0 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 5.0
# -----------------------
# S: [1 1 2 2 1 0 0 2 0]  with action:  5  based on  [0, 3, 1, 7, 4, 2]
# Sa: [1 1 2 2 1 1 0 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 0 0 2 0]  with action:  6  based on  [0, 3, 1, 7, 4, 2]
# Sa: [1 1 2 2 1 0 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 0 0 2 0]  with action:  8  based on  [0, 3, 1, 7, 4, 2]
# Sa: [1 1 2 2 1 0 0 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 0 2 0]  with action:  2  based on  [0, 3, 1, 7, 4, 5]
# Sa: [1 1 1 2 1 2 0 2 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 0 2 0]  with action:  6  based on  [0, 3, 1, 7, 4, 5]
# Sa: [1 1 0 2 1 2 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 0 2 0]  with action:  8  based on  [0, 3, 1, 7, 4, 5]
# Sa: [1 1 0 2 1 2 0 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 2 2 0]  with action:  2  based on  [0, 3, 1, 7, 4, 6]
# Sa: [1 1 1 2 1 0 2 2 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 2 2 0]  with action:  5  based on  [0, 3, 1, 7, 4, 6]
# Sa: [1 1 0 2 1 1 2 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 2 2 0]  with action:  8  based on  [0, 3, 1, 7, 4, 6]
# Sa: [1 1 0 2 1 0 2 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 0 2 2]  with action:  2  based on  [0, 3, 1, 7, 4, 8]
# Sa: [1 1 1 2 1 0 0 2 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 0 2 2]  with action:  5  based on  [0, 3, 1, 7, 4, 8]
# Sa: [1 1 0 2 1 1 0 2 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 0 2 2]  with action:  6  based on  [0, 3, 1, 7, 4, 8]
# Sa: [1 1 0 2 1 0 1 2 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 0 2 0]  with action:  5  based on  [0, 3, 1, 7]
# Sa: [1 1 0 2 0 1 0 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 2.0
# -----------------------
# S: [1 1 2 2 0 1 0 2 0]  with action:  4  based on  [0, 3, 1, 7, 5, 2]
# Sa: [1 1 2 2 1 1 0 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 1 0 2 0]  with action:  6  based on  [0, 3, 1, 7, 5, 2]
# Sa: [1 1 2 2 0 1 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 1 0 2 0]  with action:  8  based on  [0, 3, 1, 7, 5, 2]
# Sa: [1 1 2 2 0 1 0 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 0 2 0]  with action:  2  based on  [0, 3, 1, 7, 5, 4]
# Sa: [1 1 1 2 2 1 0 2 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 0 2 0]  with action:  6  based on  [0, 3, 1, 7, 5, 4]
# Sa: [1 1 0 2 2 1 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 0 2 0]  with action:  8  based on  [0, 3, 1, 7, 5, 4]
# Sa: [1 1 0 2 2 1 0 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 2 2 0]  with action:  2  based on  [0, 3, 1, 7, 5, 6]
# Sa: [1 1 1 2 0 1 2 2 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 2 2 0]  with action:  4  based on  [0, 3, 1, 7, 5, 6]
# Sa: [1 1 0 2 1 1 2 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 2 2 0]  with action:  8  based on  [0, 3, 1, 7, 5, 6]
# Sa: [1 1 0 2 0 1 2 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 0 2 2]  with action:  2  based on  [0, 3, 1, 7, 5, 8]
# Sa: [1 1 1 2 0 1 0 2 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 0 2 2]  with action:  4  based on  [0, 3, 1, 7, 5, 8]
# Sa: [1 1 0 2 1 1 0 2 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 0 2 2]  with action:  6  based on  [0, 3, 1, 7, 5, 8]
# Sa: [1 1 0 2 0 1 1 2 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 0 2 0]  with action:  6  based on  [0, 3, 1, 7]
# Sa: [1 1 0 2 0 0 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 2.0
# -----------------------
# S: [1 1 2 2 0 0 1 2 0]  with action:  4  based on  [0, 3, 1, 7, 6, 2]
# Sa: [1 1 2 2 1 0 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 1 2 0]  with action:  5  based on  [0, 3, 1, 7, 6, 2]
# Sa: [1 1 2 2 0 1 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 1 2 0]  with action:  8  based on  [0, 3, 1, 7, 6, 2]
# Sa: [1 1 2 2 0 0 1 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 1 2 0]  with action:  2  based on  [0, 3, 1, 7, 6, 4]
# Sa: [1 1 1 2 2 0 1 2 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 1 2 0]  with action:  5  based on  [0, 3, 1, 7, 6, 4]
# Sa: [1 1 0 2 2 1 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 1 2 0]  with action:  8  based on  [0, 3, 1, 7, 6, 4]
# Sa: [1 1 0 2 2 0 1 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 1 2 0]  with action:  2  based on  [0, 3, 1, 7, 6, 5]
# Sa: [1 1 1 2 0 2 1 2 0]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 1 2 0]  with action:  4  based on  [0, 3, 1, 7, 6, 5]
# Sa: [1 1 0 2 1 2 1 2 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 1 2 0]  with action:  8  based on  [0, 3, 1, 7, 6, 5]
# Sa: [1 1 0 2 0 2 1 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 1 2 2]  with action:  2  based on  [0, 3, 1, 7, 6, 8]
# Sa: [1 1 1 2 0 0 1 2 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 1 2 2]  with action:  4  based on  [0, 3, 1, 7, 6, 8]
# Sa: [1 1 0 2 1 0 1 2 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 1 2 2]  with action:  5  based on  [0, 3, 1, 7, 6, 8]
# Sa: [1 1 0 2 0 1 1 2 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 0 2 0]  with action:  8  based on  [0, 3, 1, 7]
# Sa: [1 1 0 2 0 0 0 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 6.0
# -----------------------
# S: [1 1 2 2 0 0 0 2 1]  with action:  4  based on  [0, 3, 1, 7, 8, 2]
# Sa: [1 1 2 2 1 0 0 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 0 2 1]  with action:  5  based on  [0, 3, 1, 7, 8, 2]
# Sa: [1 1 2 2 0 1 0 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 0 2 1]  with action:  6  based on  [0, 3, 1, 7, 8, 2]
# Sa: [1 1 2 2 0 0 1 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 2 1]  with action:  2  based on  [0, 3, 1, 7, 8, 4]
# Sa: [1 1 1 2 2 0 0 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 2 1]  with action:  5  based on  [0, 3, 1, 7, 8, 4]
# Sa: [1 1 0 2 2 1 0 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 2 1]  with action:  6  based on  [0, 3, 1, 7, 8, 4]
# Sa: [1 1 0 2 2 0 1 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 2 1]  with action:  2  based on  [0, 3, 1, 7, 8, 5]
# Sa: [1 1 1 2 0 2 0 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 2 1]  with action:  4  based on  [0, 3, 1, 7, 8, 5]
# Sa: [1 1 0 2 1 2 0 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 2 1]  with action:  6  based on  [0, 3, 1, 7, 8, 5]
# Sa: [1 1 0 2 0 2 1 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 2 1]  with action:  2  based on  [0, 3, 1, 7, 8, 6]
# Sa: [1 1 1 2 0 0 2 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 2 1]  with action:  4  based on  [0, 3, 1, 7, 8, 6]
# Sa: [1 1 0 2 1 0 2 2 1]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 2 1]  with action:  5  based on  [0, 3, 1, 7, 8, 6]
# Sa: [1 1 0 2 0 1 2 2 1]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 0 0 2]  with action:  2  based on  [0, 3, 1, 8]
# Sa: [1 1 1 2 0 0 0 0 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 0 0 2]  with action:  4  based on  [0, 3, 1, 8]
# Sa: [1 1 0 2 1 0 0 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 6.0
# -----------------------
# S: [1 1 2 2 1 0 0 0 2]  with action:  5  based on  [0, 3, 1, 8, 4, 2]
# Sa: [1 1 2 2 1 1 0 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 0 0 0 2]  with action:  6  based on  [0, 3, 1, 8, 4, 2]
# Sa: [1 1 2 2 1 0 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 1 0 0 0 2]  with action:  7  based on  [0, 3, 1, 8, 4, 2]
# Sa: [1 1 2 2 1 0 0 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 0 0 2]  with action:  2  based on  [0, 3, 1, 8, 4, 5]
# Sa: [1 1 1 2 1 2 0 0 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 0 0 2]  with action:  6  based on  [0, 3, 1, 8, 4, 5]
# Sa: [1 1 0 2 1 2 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 2 0 0 2]  with action:  7  based on  [0, 3, 1, 8, 4, 5]
# Sa: [1 1 0 2 1 2 0 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 2 0 2]  with action:  2  based on  [0, 3, 1, 8, 4, 6]
# Sa: [1 1 1 2 1 0 2 0 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 2 0 2]  with action:  5  based on  [0, 3, 1, 8, 4, 6]
# Sa: [1 1 0 2 1 1 2 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 2 0 2]  with action:  7  based on  [0, 3, 1, 8, 4, 6]
# Sa: [1 1 0 2 1 0 2 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 0 2 2]  with action:  2  based on  [0, 3, 1, 8, 4, 7]
# Sa: [1 1 1 2 1 0 0 2 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 0 2 2]  with action:  5  based on  [0, 3, 1, 8, 4, 7]
# Sa: [1 1 0 2 1 1 0 2 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 1 0 0 2 2]  with action:  6  based on  [0, 3, 1, 8, 4, 7]
# Sa: [1 1 0 2 1 0 1 2 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 0 0 2]  with action:  5  based on  [0, 3, 1, 8]
# Sa: [1 1 0 2 0 1 0 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 3.0
# -----------------------
# S: [1 1 2 2 0 1 0 0 2]  with action:  4  based on  [0, 3, 1, 8, 5, 2]
# Sa: [1 1 2 2 1 1 0 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 1 0 0 2]  with action:  6  based on  [0, 3, 1, 8, 5, 2]
# Sa: [1 1 2 2 0 1 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 1 0 0 2]  with action:  7  based on  [0, 3, 1, 8, 5, 2]
# Sa: [1 1 2 2 0 1 0 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 0 0 2]  with action:  2  based on  [0, 3, 1, 8, 5, 4]
# Sa: [1 1 1 2 2 1 0 0 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 0 0 2]  with action:  6  based on  [0, 3, 1, 8, 5, 4]
# Sa: [1 1 0 2 2 1 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 1 0 0 2]  with action:  7  based on  [0, 3, 1, 8, 5, 4]
# Sa: [1 1 0 2 2 1 0 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 2 0 2]  with action:  2  based on  [0, 3, 1, 8, 5, 6]
# Sa: [1 1 1 2 0 1 2 0 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 2 0 2]  with action:  4  based on  [0, 3, 1, 8, 5, 6]
# Sa: [1 1 0 2 1 1 2 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 2 0 2]  with action:  7  based on  [0, 3, 1, 8, 5, 6]
# Sa: [1 1 0 2 0 1 2 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 0 2 2]  with action:  2  based on  [0, 3, 1, 8, 5, 7]
# Sa: [1 1 1 2 0 1 0 2 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 0 2 2]  with action:  4  based on  [0, 3, 1, 8, 5, 7]
# Sa: [1 1 0 2 1 1 0 2 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 1 0 2 2]  with action:  6  based on  [0, 3, 1, 8, 5, 7]
# Sa: [1 1 0 2 0 1 1 2 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 0 0 2]  with action:  6  based on  [0, 3, 1, 8]
# Sa: [1 1 0 2 0 0 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 3.0
# -----------------------
# S: [1 1 2 2 0 0 1 0 2]  with action:  4  based on  [0, 3, 1, 8, 6, 2]
# Sa: [1 1 2 2 1 0 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 1 0 2]  with action:  5  based on  [0, 3, 1, 8, 6, 2]
# Sa: [1 1 2 2 0 1 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 1 0 2]  with action:  7  based on  [0, 3, 1, 8, 6, 2]
# Sa: [1 1 2 2 0 0 1 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 1 0 2]  with action:  2  based on  [0, 3, 1, 8, 6, 4]
# Sa: [1 1 1 2 2 0 1 0 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 1 0 2]  with action:  5  based on  [0, 3, 1, 8, 6, 4]
# Sa: [1 1 0 2 2 1 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 1 0 2]  with action:  7  based on  [0, 3, 1, 8, 6, 4]
# Sa: [1 1 0 2 2 0 1 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 1 0 2]  with action:  2  based on  [0, 3, 1, 8, 6, 5]
# Sa: [1 1 1 2 0 2 1 0 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 1 0 2]  with action:  4  based on  [0, 3, 1, 8, 6, 5]
# Sa: [1 1 0 2 1 2 1 0 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 1 0 2]  with action:  7  based on  [0, 3, 1, 8, 6, 5]
# Sa: [1 1 0 2 0 2 1 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 1 2 2]  with action:  2  based on  [0, 3, 1, 8, 6, 7]
# Sa: [1 1 1 2 0 0 1 2 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 1 2 2]  with action:  4  based on  [0, 3, 1, 8, 6, 7]
# Sa: [1 1 0 2 1 0 1 2 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 1 2 2]  with action:  5  based on  [0, 3, 1, 8, 6, 7]
# Sa: [1 1 0 2 0 1 1 2 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 0 0 2]  with action:  7  based on  [0, 3, 1, 8]
# Sa: [1 1 0 2 0 0 0 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 6.0
# -----------------------
# S: [1 1 2 2 0 0 0 1 2]  with action:  4  based on  [0, 3, 1, 8, 7, 2]
# Sa: [1 1 2 2 1 0 0 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 0 1 2]  with action:  5  based on  [0, 3, 1, 8, 7, 2]
# Sa: [1 1 2 2 0 1 0 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 2 2 0 0 0 1 2]  with action:  6  based on  [0, 3, 1, 8, 7, 2]
# Sa: [1 1 2 2 0 0 1 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 1 2]  with action:  2  based on  [0, 3, 1, 8, 7, 4]
# Sa: [1 1 1 2 2 0 0 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 1 2]  with action:  5  based on  [0, 3, 1, 8, 7, 4]
# Sa: [1 1 0 2 2 1 0 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 2 0 0 1 2]  with action:  6  based on  [0, 3, 1, 8, 7, 4]
# Sa: [1 1 0 2 2 0 1 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 1 2]  with action:  2  based on  [0, 3, 1, 8, 7, 5]
# Sa: [1 1 1 2 0 2 0 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 1 2]  with action:  4  based on  [0, 3, 1, 8, 7, 5]
# Sa: [1 1 0 2 1 2 0 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 2 0 1 2]  with action:  6  based on  [0, 3, 1, 8, 7, 5]
# Sa: [1 1 0 2 0 2 1 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 1 2]  with action:  2  based on  [0, 3, 1, 8, 7, 6]
# Sa: [1 1 1 2 0 0 2 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 1 2]  with action:  4  based on  [0, 3, 1, 8, 7, 6]
# Sa: [1 1 0 2 1 0 2 1 2]
# [Returns]
# E_R = 1.0, E_V_Saa = 0.0
# -----------------------
# S: [1 1 0 2 0 0 2 1 2]  with action:  5  based on  [0, 3, 1, 8, 7, 6]
# Sa: [1 1 0 2 0 1 2 1 2]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
