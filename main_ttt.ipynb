# %%
# %load_ext autoreload
# %autoreload 2

#import numba
import tictactoe
import numpy as np
import matplotlib.pyplot as plt

# %%
tictactoe.main()
# Out:
# == Start TicTacToe Aget Framework ==
# - Developed by Sungjin Kim, 2020
#
# 0) Playing a game
# 1) Learning a new agent
# 2) Testing code
# What do you want? (0=deafult)  2
# Start to test code...
# How many episode do you want to play?(default=10000)
# Play by two random players
# 0 [0, 1, 0, 1, 0]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.01
# 1000 [135, 443, 423, 581, 285]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.01
# 2000 [272, 887, 842, 1148, 581]
# S = [0,0,0, 0,0,0, 0,0,0]
# ...

# %%
tictactoe.main()
# Out:
# == Start TicTacToe Aget Framework ==
# - Developed by Sungjin Kim, 2020
#
# 0) Playing a game
# 1) Learning a new agent
# 2) Testing code
# What do you want? (0=deafult)  2
# Start to test code...
# How many episode do you want to play?(default=10000)
# Play by two random players
# 0 [0, 0, 1, 0, 1]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.01
# 1000 [119, 430, 452, 599, 283]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.01
# 2000 [251, 850, 900, 1188, 562]
# S = [0,0,0, 0,0,0, 0,0,0]
# ...

# %%
tictactoe.main()
# Out:
# == Start TicTacToe Aget Framework ==
# - Developed by Sungjin Kim, 2020
#
# 0) Playing a game
# 1) Learning a new agent
# 2) Testing code
# What do you want? (0=deafult)  1
# ------------------------------
# Start to learn a new agent...
# How many episode do you want to learn?(default=10000)
# 0) MC Backup with e-Greedy
# 1) Q-learning
# What learning method do you want to use? (0=default)  1
# 0 [1, 0, 0, 0, 1]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# 1000 [133, 434, 434, 339, 228]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['2.6e-10', '2.4e-06', '5.8e-08', '1.8e-03', '4.5e-08', '1.7e-06', '4.9e-06', '0.0e+00', '1.5e-08']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# ...

# %%
tictactoe.playing_stage_random(10000, True)
# Out:
# 0 [0, 1, 0, 1, 0]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.01
# 1000 [118, 449, 434, 608, 275]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.01
# 2000 [246, 876, 879, 1201, 554]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.01
# 3000 [379, 1306, 1316, 1783, 839]
# ...

# %%
tictactoe.learning_stage_dqn(10000, fig_flag=True)
# Out:
# 0 [0, 0, 1, 0, 0]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# 1000 [133, 494, 374, 384, 243]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['7.4e-06', '1.6e-06', '9.7e-06', '7.3e-06', '4.1e-06', '2.2e-08', '7.3e-06', '8.3e-07', '1.4e-03']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# 2000 [243, 1025, 733, 802, 466]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['5.7e-05', '4.1e-06', '3.2e-05', '9.8e-06', '9.9e-06', '1.2e-07', '1.5e-05', '5.0e-06', '1.6e-02']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# 3000 [331, 1583, 1087, 1209, 705]
# ...

# %%
tictactoe.learning_stage_dqn(10000, fig_flag=True)
# Out:
# 0 [1, 0, 0, 0, 0]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# 1000 [117, 442, 442, 594, 290]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['2.9e-08', '1.5e-05', '5.9e-08', '8.5e-07', '5.7e-06', '1.7e-03', '1.7e-06', '1.6e-06', '8.3e-07']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# 2000 [238, 936, 827, 1172, 591]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['9.3e-07', '1.9e-05', '2.3e-05', '1.2e-05', '5.8e-05', '1.6e-02', '9.0e-06', '1.5e-05', '5.8e-06']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# 3000 [347, 1503, 1151, 1751, 903]
# ...

# %%
tictactoe.learning_stage_dqn(10000, fig_flag=True)
# Out:
# 0 [0, 0, 1, 0, 1, 0, 0, 0, 1]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# 1000 [114, 471, 416, 602, 285, 316, 155, 286, 130]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['3.2e-06', '4.1e-06', '2.9e-08', '5.9e-06', '0.0e+00', '2.4e-06', '2.0e-03', '1.3e-10', '8.7e-07']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# 2000 [224, 1019, 758, 1222, 555, 680, 339, 542, 216]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['1.6e-05', '1.1e-05', '2.8e-06', '3.3e-05', '4.2e-06', '1.7e-05', '1.9e-02', '4.1e-06', '8.4e-06']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# ...

# %%
tictactoe.learning_stage_dqn(10000, fig_flag=True)
# Out:
# 0 [0, 1, 0, 1, 0, 1, 0, 0, 0]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# 1000 [116, 463, 422, 609, 276, 319, 144, 290, 132]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['4.9e-06', '3.2e-06', '1.1e-05', '3.3e-06', '6.6e-11', '3.2e-06', '3.3e-03', '2.6e-06', '1.5e-08']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# 2000 [219, 1015, 767, 1194, 588, 666, 349, 528, 239]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['1.5e-05', '2.8e-05', '4.0e-05', '2.2e-05', '5.6e-05', '1.2e-05', '3.2e-02', '5.3e-05', '1.7e-06']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# ...

# %%
tictactoe.learning_stage_dqn(10000, fig_flag=True)
# Out:
# 0 [0, 1, 0, 1, 0, 1, 0, 0, 0]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# 1000 [112, 500, 389, 616, 273, 336, 164, 280, 109]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['1.6e-03', '2.9e-08', '0.0e+00', '3.2e-06', '1.5e-08', '2.0e-10', '4.9e-06', '1.6e-06', '2.4e-06']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# 2000 [229, 1038, 734, 1202, 570, 681, 357, 521, 213]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['1.3e-02', '1.8e-05', '1.4e-05', '1.2e-05', '9.8e-06', '8.1e-07', '4.4e-05', '1.6e-06', '1.5e-05']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.4
# ...

# %%
tictactoe.learning_stage_dqn(10000, epsilon=0.2, fig_flag=True)
# Out:
# 0 [0, 1, 0, 1, 0, 1, 0, 0, 0]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 1000 [134, 448, 419, 545, 322, 281, 167, 264, 155]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '2.0e-10', '0.0e+00', '9.8e-11', '8.2e-07', '2.1e-03', '8.2e-07', '2.6e-10', '7.4e-09']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# 2000 [263, 959, 779, 1109, 629, 610, 349, 499, 280]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['2.5e-06', '2.4e-06', '2.4e-06', '1.7e-06', '2.5e-06', '1.9e-02', '3.3e-06', '3.0e-08', '2.9e-08']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.2
# ...

# %%
tictactoe.learning_stage_dqn(10000, epsilon=0.9, fig_flag=True)
# Out:
# 0 [0, 1, 0, 1, 0, 1, 0, 0, 0]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.9
# 1000 [130, 456, 415, 582, 289, 300, 156, 282, 133]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['9.0e-06', '5.7e-06', '5.0e-06', '1.1e-05', '1.6e-05', '2.2e-05', '8.2e-05', '4.9e-06', '1.7e-06']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.9
# 2000 [271, 901, 829, 1164, 566, 601, 300, 563, 266]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['7.4e-05', '3.8e-05', '4.4e-05', '5.8e-05', '7.8e-05', '1.1e-04', '2.9e-04', '3.8e-05', '2.1e-05']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.9
# ...

# %%
tictactoe.learning_stage_dqn(10000, epsilon=0.1, fig_flag=True)
# Out:
# 0 [0, 1, 0, 1, 0, 1, 0, 0, 0]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.1
# 1000 [122, 521, 358, 594, 285, 340, 181, 254, 104]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['0.0e+00', '8.1e-07', '6.3e-03', '2.4e-06', '0.0e+00', '0.0e+00', '0.0e+00', '1.5e-08', '2.4e-06']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.1
# 2000 [239, 1131, 631, 1167, 595, 724, 407, 443, 188]
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['1.6e-06', '8.1e-07', '7.0e-02', '5.7e-06', '0.0e+00', '0.0e+00', '0.0e+00', '1.2e-07', '4.1e-06']
# Qsa[1][0,:] ['0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00', '0.0e+00']
# Exproration: Epsilon= 0.1
# ...
