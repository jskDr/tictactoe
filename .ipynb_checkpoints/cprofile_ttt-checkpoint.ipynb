# %%
# %load_ext autoreload
# %autoreload 2
import tictactoe
import cProfile
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def run():
    epsilon_d = {'first value':0.4, 'second value':0.1, 'epsilon change episode':20}
    _= tictactoe.learning_stage_cnndqn_variable_epsilon(N_episodes=100, epsilon_d=epsilon_d, agent_type=2, fig_flag=True)

# cProfile.run('run()')
run()
# Out:
# WARNING:tensorflow:Layer cnn_agent_30 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer cnn_agent_31 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer cnn_agent_28 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
#
# Finished episode: # 0
# cnt:  [0, 0, 1, 0, 1, 0, 0, 0, 1]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# WARNING:tensorflow:Layer cnn_agent_29 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# Qsa[0][0,:] ['-2.7e-02', '6.7e-03', '-1.7e-02', '5.2e-02', '-5.4e-02', '3.4e-02', '3.3e-02', '-6.4e-02', '-1.5e-02']
# Qsa[1][0,:] ['5.6e-03', '-4.0e-02', '2.4e-02', '1.6e-02', '3.4e-02', '2.8e-02', '1.0e-01', '-8.1e-02', '-4.6e-02']
# Exproration: Epsilon= 0.4
#
# Finished episode: # 10
# cnt:  [0, 1, 10, 4, 7, 0, 1, 4, 6]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['-1.4e-02', '1.7e-02', '-7.3e-03', '6.3e-02', '-3.1e-02', '4.7e-02', '3.8e-02', '-4.5e-02', '-5.4e-03']
# Qsa[1][0,:] ['5.6e-03', '-4.0e-02', '2.4e-02', '1.6e-02', '3.4e-02', '2.8e-02', '1.0e-01', '-8.1e-02', '-4.6e-02']
# Exproration: Epsilon= 0.4
#
# Finished episode: # 20
# cnt:  [3, 1, 17, 9, 9, 0, 1, 9, 8]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['-4.7e-03', '2.6e-02', '2.7e-06', '7.0e-02', '-7.7e-03', '5.1e-02', '3.6e-02', '-2.4e-02', '-1.7e-03']
# Qsa[1][0,:] ['5.6e-03', '-4.0e-02', '2.4e-02', '1.6e-02', '3.4e-02', '2.8e-02', '1.0e-01', '-8.1e-02', '-4.6e-02']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 30
# cnt:  [3, 1, 27, 14, 14, 0, 1, 14, 13]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['-9.5e-03', '2.0e-02', '-3.7e-03', '5.3e-02', '-1.0e-02', '3.5e-02', '2.4e-02', '-3.5e-02', '-1.1e-02']
# Qsa[1][0,:] ['5.6e-03', '-4.0e-02', '2.4e-02', '1.6e-02', '3.4e-02', '2.8e-02', '1.0e-01', '-8.1e-02', '-4.6e-02']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 40
# cnt:  [5, 1, 35, 19, 17, 0, 1, 19, 16]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['-1.5e-02', '1.6e-02', '-7.3e-03', '3.5e-02', '-1.6e-02', '2.3e-02', '1.5e-02', '-5.3e-02', '-1.7e-02']
# Qsa[1][0,:] ['5.6e-03', '-4.0e-02', '2.4e-02', '1.6e-02', '3.4e-02', '2.8e-02', '1.0e-01', '-8.1e-02', '-4.6e-02']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 50
# cnt:  [6, 2, 43, 25, 20, 1, 1, 24, 19]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['-1.3e-02', '1.8e-02', '-3.3e-03', '3.6e-02', '-8.4e-03', '2.3e-02', '1.5e-02', '-5.5e-02', '-1.5e-02']
# Qsa[1][0,:] ['5.6e-03', '-4.0e-02', '2.4e-02', '1.6e-02', '3.4e-02', '2.8e-02', '1.0e-01', '-8.1e-02', '-4.6e-02']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 60
# cnt:  [6, 2, 53, 30, 25, 1, 1, 29, 24]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['-1.0e-02', '2.0e-02', '2.9e-04', '4.2e-02', '-1.3e-04', '2.3e-02', '8.8e-03', '-5.2e-02', '-1.6e-02']
# Qsa[1][0,:] ['5.6e-03', '-4.0e-02', '2.4e-02', '1.6e-02', '3.4e-02', '2.8e-02', '1.0e-01', '-8.1e-02', '-4.6e-02']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 70
# cnt:  [6, 3, 62, 36, 29, 2, 1, 34, 28]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['-1.4e-02', '1.4e-02', '-9.9e-04', '3.6e-02', '-1.7e-03', '1.8e-02', '1.9e-03', '-5.5e-02', '-2.1e-02']
# Qsa[1][0,:] ['5.6e-03', '-4.0e-02', '2.4e-02', '1.6e-02', '3.4e-02', '2.8e-02', '1.0e-01', '-8.1e-02', '-4.6e-02']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 80
# cnt:  [6, 3, 72, 41, 34, 2, 1, 39, 33]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['-1.1e-02', '1.5e-02', '5.3e-03', '4.0e-02', '6.2e-03', '2.1e-02', '-1.3e-03', '-4.6e-02', '-2.1e-02']
# Qsa[1][0,:] ['5.6e-03', '-4.0e-02', '2.4e-02', '1.6e-02', '3.4e-02', '2.8e-02', '1.0e-01', '-8.1e-02', '-4.6e-02']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 90
# cnt:  [8, 5, 78, 48, 35, 4, 1, 44, 34]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['1.4e-03', '2.6e-02', '1.8e-02', '5.5e-02', '2.8e-02', '3.1e-02', '2.7e-03', '-2.9e-02', '-1.4e-02']
# Qsa[1][0,:] ['5.6e-03', '-4.0e-02', '2.4e-02', '1.6e-02', '3.4e-02', '2.8e-02', '1.0e-01', '-8.1e-02', '-4.6e-02']
# Exproration: Epsilon= 0.1
# -------------------
# 100 Last cnt:[10, 7, 83, 55, 35, 6, 1, 49, 34], Normalized last cnt:[0.1  0.07 0.83 0.55 0.35 0.06 0.01 0.49 0.34]
# (100, 9) (100, 1)

# %%
def run():
    epsilon_d = {'first value':0.4, 'second value':0.1, 'epsilon change episode':20}
    _= tictactoe.learning_stage_cnndqn_variable_epsilon(N_episodes=100, epsilon_d=epsilon_d, agent_type=2, fig_flag=True)

cProfile.run('run()')
#run()
# Out:
# WARNING:tensorflow:Layer cnn_agent_34 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer cnn_agent_35 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer cnn_agent_32 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
#
# Finished episode: # 0
# cnt:  [0, 0, 1, 0, 1, 0, 0, 0, 1]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# WARNING:tensorflow:Layer cnn_agent_33 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# Qsa[0][0,:] ['1.5e-03', '5.4e-03', '3.3e-02', '-1.5e-02', '-1.0e-01', '4.1e-02', '-2.4e-02', '9.7e-04', '8.4e-02']
# Qsa[1][0,:] ['-1.4e-02', '-6.3e-02', '-3.4e-02', '-3.7e-02', '-8.8e-02', '-1.3e-01', '-3.6e-01', '-3.5e-01', '-1.2e-01']
# Exproration: Epsilon= 0.4
#
# Finished episode: # 10
# cnt:  [0, 0, 11, 5, 6, 0, 0, 5, 6]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['1.7e-02', '2.9e-02', '4.0e-02', '3.2e-03', '-6.8e-02', '6.1e-02', '2.5e-06', '3.0e-02', '6.4e-02']
# Qsa[1][0,:] ['-1.4e-02', '-6.3e-02', '-3.4e-02', '-3.7e-02', '-8.8e-02', '-1.3e-01', '-3.6e-01', '-3.5e-01', '-1.2e-01']
# Exproration: Epsilon= 0.4
#
# Finished episode: # 20
# cnt:  [2, 1, 18, 11, 8, 1, 0, 10, 8]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['3.5e-02', '5.4e-02', '5.2e-02', '1.9e-02', '-3.3e-02', '8.6e-02', '3.3e-02', '6.1e-02', '6.9e-02']
# Qsa[1][0,:] ['-1.4e-02', '-6.3e-02', '-3.4e-02', '-3.7e-02', '-8.8e-02', '-1.3e-01', '-3.6e-01', '-3.5e-01', '-1.2e-01']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 30
# cnt:  [2, 2, 27, 17, 12, 2, 0, 15, 12]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['4.1e-02', '5.9e-02', '5.5e-02', '1.8e-02', '-2.5e-02', '8.0e-02', '4.1e-02', '7.0e-02', '6.9e-02']
# Qsa[1][0,:] ['-1.4e-02', '-6.3e-02', '-3.4e-02', '-3.7e-02', '-8.8e-02', '-1.3e-01', '-3.6e-01', '-3.5e-01', '-1.2e-01']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 40
# cnt:  [3, 3, 35, 23, 15, 3, 0, 20, 15]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['5.0e-02', '7.1e-02', '6.4e-02', '2.4e-02', '-1.3e-02', '8.9e-02', '5.4e-02', '7.9e-02', '8.1e-02']
# Qsa[1][0,:] ['-1.4e-02', '-6.3e-02', '-3.4e-02', '-3.7e-02', '-8.8e-02', '-1.3e-01', '-3.6e-01', '-3.5e-01', '-1.2e-01']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 50
# cnt:  [3, 3, 45, 28, 20, 3, 0, 25, 20]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['4.8e-02', '6.3e-02', '5.9e-02', '2.1e-02', '-1.9e-02', '8.4e-02', '5.3e-02', '7.1e-02', '7.3e-02']
# Qsa[1][0,:] ['-1.4e-02', '-6.3e-02', '-3.4e-02', '-3.7e-02', '-8.8e-02', '-1.3e-01', '-3.6e-01', '-3.5e-01', '-1.2e-01']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 60
# cnt:  [4, 3, 54, 33, 24, 3, 0, 30, 24]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['4.2e-02', '4.7e-02', '5.2e-02', '1.2e-02', '-3.2e-02', '7.1e-02', '4.5e-02', '5.6e-02', '5.7e-02']
# Qsa[1][0,:] ['-1.4e-02', '-6.3e-02', '-3.4e-02', '-3.7e-02', '-8.8e-02', '-1.3e-01', '-3.6e-01', '-3.5e-01', '-1.2e-01']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 70
# cnt:  [5, 3, 63, 38, 28, 3, 0, 35, 28]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['3.6e-02', '3.2e-02', '4.5e-02', '2.8e-03', '-4.3e-02', '5.3e-02', '3.6e-02', '3.2e-02', '4.5e-02']
# Qsa[1][0,:] ['-1.4e-02', '-6.3e-02', '-3.4e-02', '-3.7e-02', '-8.8e-02', '-1.3e-01', '-3.6e-01', '-3.5e-01', '-1.2e-01']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 80
# cnt:  [9, 3, 69, 43, 29, 3, 0, 40, 29]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['4.3e-02', '4.2e-02', '4.9e-02', '1.1e-02', '-2.9e-02', '6.6e-02', '5.8e-02', '5.6e-02', '5.7e-02']
# Qsa[1][0,:] ['-1.4e-02', '-6.3e-02', '-3.4e-02', '-3.7e-02', '-8.8e-02', '-1.3e-01', '-3.6e-01', '-3.5e-01', '-1.2e-01']
# Exproration: Epsilon= 0.1
#
# Finished episode: # 90
# cnt:  [9, 4, 78, 49, 33, 4, 0, 45, 33]
# Play order:1, P_no:1
# S = [0,0,0, 0,0,0, 0,0,0]
# Qsa[0][0,:] ['4.4e-02', '4.4e-02', '4.8e-02', '1.2e-02', '-2.6e-02', '6.9e-02', '6.7e-02', '6.1e-02', '6.0e-02']
# Qsa[1][0,:] ['-1.4e-02', '-6.3e-02', '-3.4e-02', '-3.7e-02', '-8.8e-02', '-1.3e-01', '-3.6e-01', '-3.5e-01', '-1.2e-01']
# Exproration: Epsilon= 0.1
# -------------------
# 100 Last cnt:[9, 5, 86, 55, 36, 5, 0, 50, 36], Normalized last cnt:[0.09 0.05 0.86 0.55 0.36 0.05 0.   0.5  0.36]
# (100, 9) (100, 1)
#          24036081 function calls (23263487 primitive calls) in 24.772 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       190    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(all)
#      2046    0.002    0.000    0.031    0.000 <__array_function__ internals>:2(amax)
#      1296    0.001    0.000    0.012    0.000 <__array_function__ internals>:2(amin)
#       908    0.001    0.000    0.011    0.000 <__array_function__ internals>:2(any)
#       400    0.000    0.000    0.004    0.000 <__array_function__ internals>:2(around)
#       300    0.000    0.000    0.006    0.000 <__array_function__ internals>:2(array_equal)
#        42    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(atleast_1d)
#        44    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(atleast_2d)
#        77    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(atleast_3d)
#       246    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(broadcast_arrays)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(can_cast)
#        84    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(clip)
#       250    0.000    0.000    0.004    0.000 <__array_function__ internals>:2(column_stack)
#       342    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(concatenate)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#       190    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(cumsum)
#        32    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diff)
#      1397    0.001    0.000    0.009    0.000 <__array_function__ internals>:2(dot)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(empty_like)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(full_like)
#        32    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(hstack)
#        46    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(isclose)
#        10    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(linspace)
#       178    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(ndim)
#        84    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(nonzero)
#     10826    0.015    0.000    0.285    0.000 <__array_function__ internals>:2(prod)
#        80    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(ptp)
#        56    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(result_type)
#       400    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(round_)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(sum)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(tile)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(unravel_index)
#        44    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(vstack)
#       503    0.001    0.000    0.002    0.000 <__array_function__ internals>:2(where)
#       305    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#        50    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#         1    0.000    0.000   24.804   24.804 <ipython-input-17-51eca0e363b8>:1(run)
#         1    0.000    0.000   24.805   24.805 <string>:1(<module>)
#       836    0.000    0.000    0.001    0.000 <string>:1(__new__)
#         4    0.000    0.000    0.002    0.001 __init__.py:1002(flush)
#         4    0.000    0.000    0.003    0.001 __init__.py:1013(emit)
#         4    0.000    0.000    0.000    0.000 __init__.py:117(getLevelName)
#         2    0.000    0.000    0.000    0.000 __init__.py:1216(getLogger)
#         1    0.000    0.000    0.000    0.000 __init__.py:1322(get_backend)
#         2    0.000    0.000    0.000    0.000 __init__.py:1342(is_interactive)
#       334    0.001    0.000    0.001    0.000 __init__.py:1373(is_math_text)
#         4    0.000    0.000    0.003    0.001 __init__.py:1380(warning)
#      1046    0.001    0.000    0.004    0.000 __init__.py:1382(_to_unmasked_float_array)
#        40    0.000    0.000    0.000    0.000 __init__.py:1393(_check_1d)
#        34    0.000    0.000    0.000    0.000 __init__.py:143(__init__)
#         4    0.000    0.000    0.000    0.000 __init__.py:1476(makeRecord)
#         4    0.000    0.000    0.003    0.001 __init__.py:1491(_log)
#         4    0.000    0.000    0.003    0.001 __init__.py:1516(handle)
#         4    0.000    0.000    0.003    0.001 __init__.py:1570(callHandlers)
#         4    0.000    0.000    0.000    0.000 __init__.py:1614(isEnabledFor)
#       246    0.000    0.000    0.000    0.000 __init__.py:1616(<lambda>)
#        71    0.000    0.000    0.000    0.000 __init__.py:163(connect)
#        88    0.000    0.000    0.000    0.000 __init__.py:1651(safe_first_element)
#       190    0.002    0.000    0.003    0.000 __init__.py:1673(normalize_kwargs)
#       190    0.000    0.000    0.000    0.000 __init__.py:1760(<listcomp>)
#       190    0.000    0.000    0.000    0.000 __init__.py:1765(<listcomp>)
#         2    0.000    0.000    0.000    0.000 __init__.py:180(_remove_proxy)
#         4    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#         1    0.000    0.000    0.000    0.000 __init__.py:190(disconnect)
#       294    0.000    0.000    0.000    0.000 __init__.py:1906(_str_equal)
#       193    0.000    0.000    0.000    0.000 __init__.py:1916(_str_lower_equal)
#         2    0.000    0.000    0.000    0.000 __init__.py:1925(getLogger)
#        96    0.000    0.000    0.000    0.000 __init__.py:1947(method)
#      1758    0.003    0.000    0.004    0.000 __init__.py:2012(_setattr_cm)
#       879    0.001    0.000    0.001    0.000 __init__.py:2017(<listcomp>)
#        76    0.000    0.000    0.000    0.000 __init__.py:205(process)
#         2    0.000    0.000    0.000    0.000 __init__.py:2053(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:21(get_projection_class)
#         2    0.000    0.000    0.000    0.000 __init__.py:212(_acquireLock)
#      3674    0.002    0.000    0.003    0.000 __init__.py:2151(_check_in_list)
#         2    0.000    0.000    0.000    0.000 __init__.py:221(_releaseLock)
#         4    0.000    0.000    0.000    0.000 __init__.py:232(__init__)
#         4    0.000    0.000    0.000    0.000 __init__.py:282(__init__)
#         4    0.000    0.000    0.000    0.000 __init__.py:360(getMessage)
#         2    0.000    0.000    0.000    0.000 __init__.py:388(to_filehandle)
#      2604    0.003    0.000    0.006    0.000 __init__.py:403(_make)
#         4    0.000    0.000    0.000    0.000 __init__.py:418(usesTime)
#         4    0.000    0.000    0.000    0.000 __init__.py:421(format)
#         4    0.000    0.000    0.000    0.000 __init__.py:444(open_file_cm)
#         2    0.000    0.000    0.000    0.000 __init__.py:48(get_projection_class)
#         4    0.000    0.000    0.000    0.000 __init__.py:573(usesTime)
#         4    0.000    0.000    0.000    0.000 __init__.py:579(formatMessage)
#         4    0.000    0.000    0.000    0.000 __init__.py:595(format)
#        50    0.000    0.000    0.000    0.000 __init__.py:646(__setitem__)
#         1    0.000    0.000    0.000    0.000 __init__.py:662(__init__)
#         5    0.000    0.000    0.000    0.000 __init__.py:690(push)
#         4    0.000    0.000    0.000    0.000 __init__.py:715(clear)
#         2    0.000    0.000    0.000    0.000 __init__.py:720(bubble)
#         8    0.000    0.000    0.000    0.000 __init__.py:736(filter)
#         5    0.000    0.000    0.000    0.000 __init__.py:76(__init__)
#     16973    0.009    0.000    0.012    0.000 __init__.py:810(__getitem__)
#         8    0.000    0.000    0.000    0.000 __init__.py:838(acquire)
#         8    0.000    0.000    0.000    0.000 __init__.py:845(release)
#        11    0.000    0.000    0.000    0.000 __init__.py:85(__hash__)
#         4    0.000    0.000    0.000    0.000 __init__.py:858(format)
#         4    0.000    0.000    0.003    0.001 __init__.py:881(handle)
#         2    0.000    0.000    0.000    0.000 __init__.py:913(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:914(<dictcomp>)
#       118    0.000    0.000    0.000    0.000 __init__.py:919(clean)
#       118    0.000    0.000    0.000    0.000 __init__.py:922(<listcomp>)
#       114    0.000    0.000    0.001    0.000 __init__.py:968(get_siblings)
#       114    0.000    0.000    0.000    0.000 __init__.py:972(<listcomp>)
#      5128    0.002    0.000    0.012    0.000 _asarray.py:16(asarray)
#      1387    0.001    0.000    0.003    0.000 _asarray.py:88(asanyarray)
#        10    0.000    0.000    0.017    0.002 _axes.py:1433(plot)
#         2    0.000    0.000    0.000    0.000 _axes.py:153(set_title)
#         2    0.000    0.000    0.000    0.000 _axes.py:223(set_xlabel)
#         2    0.000    0.000    0.000    0.000 _axes.py:256(set_ylabel)
#         2    0.000    0.000    0.010    0.005 _axes.py:299(legend)
#         4    0.000    0.000    0.000    0.000 _base.py:1133(_set_title_offset_trans)
#        16    0.000    0.000    0.000    0.000 _base.py:1219(get_aspect)
#         4    0.000    0.000    0.000    0.000 _base.py:1222(set_aspect)
#         4    0.000    0.000    0.000    0.000 _base.py:130(__init__)
#         4    0.000    0.000    0.000    0.000 _base.py:1304(set_adjustable)
#         4    0.000    0.000    0.000    0.000 _base.py:143(set_prop_cycle)
#        14    0.000    0.000    0.001    0.000 _base.py:1446(apply_aspect)
#        20    0.000    0.000    0.003    0.000 _base.py:154(__call__)
#        10    0.000    0.000    0.004    0.000 _base.py:1894(add_line)
#        10    0.000    0.000    0.002    0.000 _base.py:1920(_update_line_limits)
#        24    0.000    0.000    0.001    0.000 _base.py:2097(_process_unit_info)
#        48    0.000    0.000    0.001    0.000 _base.py:2100(_process_single_axis)
#        10    0.000    0.000    0.000    0.000 _base.py:2185(use_sticky_edges)
#        10    0.000    0.000    0.010    0.001 _base.py:2388(autoscale_view)
#        10    0.000    0.000    0.000    0.000 _base.py:241(_xy_from_xy)
#        10    0.000    0.000    0.000    0.000 _base.py:2415(<listcomp>)
#        10    0.000    0.000    0.000    0.000 _base.py:2416(<listcomp>)
#        10    0.000    0.000    0.000    0.000 _base.py:2417(<listcomp>)
#        20    0.001    0.000    0.010    0.000 _base.py:2425(handle_single_axis)
#        20    0.000    0.000    0.000    0.000 _base.py:2432(<listcomp>)
#        20    0.000    0.000    0.000    0.000 _base.py:2434(<listcomp>)
#        20    0.000    0.000    0.000    0.000 _base.py:2438(<listcomp>)
#        20    0.000    0.000    0.000    0.000 _base.py:2441(<listcomp>)
#        26    0.000    0.000    0.000    0.000 _base.py:2500(_get_axis_list)
#        12    0.000    0.000    0.009    0.001 _base.py:2503(_update_title_position)
#         4    0.000    0.000    0.202    0.051 _base.py:2573(draw)
#         2    0.000    0.000    0.000    0.000 _base.py:2708(set_axisbelow)
#         6    0.000    0.000    0.013    0.002 _base.py:2744(grid)
#        10    0.000    0.000    0.000    0.000 _base.py:281(_getdefaults)
#        20    0.000    0.000    0.000    0.000 _base.py:289(<genexpr>)
#         4    0.000    0.000    0.002    0.001 _base.py:2918(tick_params)
#        10    0.000    0.000    0.000    0.000 _base.py:299(_setdefaults)
#         2    0.000    0.000    0.000    0.000 _base.py:3027(set_axis_on)
#        10    0.000    0.000    0.000    0.000 _base.py:3050(xaxis_inverted)
#        10    0.000    0.000    0.000    0.000 _base.py:3064(get_xbound)
#        10    0.000    0.000    0.002    0.000 _base.py:308(_makeline)
#        10    0.000    0.000    0.001    0.000 _base.py:3080(set_xbound)
#        22    0.000    0.000    0.000    0.000 _base.py:3120(get_xlim)
#        48    0.000    0.000    0.001    0.000 _base.py:3143(_validate_converted_limits)
#        12    0.000    0.000    0.001    0.000 _base.py:3161(set_xlim)
#        36    0.000    0.000    0.000    0.000 _base.py:3288(get_xscale)
#        10    0.000    0.000    0.000    0.000 _base.py:3449(yaxis_inverted)
#        10    0.000    0.000    0.000    0.000 _base.py:3463(get_ybound)
#        10    0.000    0.000    0.001    0.000 _base.py:3479(set_ybound)
#        22    0.000    0.000    0.000    0.000 _base.py:3519(get_ylim)
#        12    0.000    0.000    0.001    0.000 _base.py:3542(set_ylim)
#        10    0.000    0.000    0.003    0.000 _base.py:363(_plot_args)
#        36    0.000    0.000    0.000    0.000 _base.py:3670(get_yscale)
#        30    0.000    0.000    0.000    0.000 _base.py:376(<genexpr>)
#         2    0.000    0.000    0.000    0.000 _base.py:3915(set_navigate)
#         2    0.000    0.000    0.000    0.000 _base.py:3931(set_navigate_mode)
#         2    0.000    0.000    0.031    0.015 _base.py:421(__init__)
#        24    0.000    0.000    0.000    0.000 _base.py:4248(get_children)
#         6    0.000    0.000    0.000    0.000 _base.py:4279(get_default_bbox_extra_artists)
#         6    0.000    0.000    0.000    0.000 _base.py:4299(<listcomp>)
#         4    0.001    0.000    0.108    0.027 _base.py:4302(get_tightbbox)
#         4    0.000    0.000    0.000    0.000 _base.py:4399(<listcomp>)
#        44    0.000    0.000    0.000    0.000 _base.py:576(get_window_extent)
#         2    0.000    0.000    0.003    0.002 _base.py:594(_init_axis)
#         2    0.000    0.000    0.000    0.000 _base.py:604(set_figure)
#         2    0.000    0.000    0.000    0.000 _base.py:624(_set_lim_and_transforms)
#   544/300    0.000    0.000    0.001    0.000 _base.py:660(get_xaxis_transform)
#        60    0.000    0.000    0.002    0.000 _base.py:684(get_xaxis_text1_transform)
#        60    0.000    0.000    0.001    0.000 _base.py:710(get_xaxis_text2_transform)
#   544/300    0.000    0.000    0.001    0.000 _base.py:736(get_yaxis_transform)
#        60    0.000    0.000    0.002    0.000 _base.py:760(get_yaxis_text1_transform)
#        60    0.000    0.000    0.001    0.000 _base.py:786(get_yaxis_text2_transform)
#         4    0.000    0.000    0.000    0.000 _base.py:812(_update_transScale)
#     12/10    0.000    0.000    0.000    0.000 _base.py:822(get_position)
#        14    0.000    0.000    0.001    0.000 _base.py:871(_set_position)
#         6    0.000    0.000    0.000    0.000 _base.py:898(set_axes_locator)
#        16    0.000    0.000    0.000    0.000 _base.py:909(get_axes_locator)
#        16    0.000    0.000    0.000    0.000 _base.py:915(_set_artist_props)
#         2    0.000    0.000    0.000    0.000 _base.py:925(_gen_axes_patch)
#         2    0.000    0.000    0.002    0.001 _base.py:942(_gen_axes_spines)
#        10    0.000    0.000    0.002    0.000 _base.py:957(<genexpr>)
#         2    0.000    0.000    0.023    0.011 _base.py:960(cla)
#     69798    0.066    0.000    0.249    0.000 _collections_abc.py:657(get)
#     69798    0.049    0.000    0.209    0.000 _collections_abc.py:664(__contains__)
#      8857    0.010    0.000    0.013    0.000 _collections_abc.py:676(items)
#      8857    0.004    0.000    0.004    0.000 _collections_abc.py:698(__init__)
#     44285    0.086    0.000    0.086    0.000 _collections_abc.py:742(__iter__)
#     22040    0.016    0.000    0.026    0.000 _collections_abc.py:879(__iter__)
#       583    0.003    0.000    0.006    0.000 _dtype.py:319(_name_get)
#        80    0.001    0.000    0.001    0.000 _methods.py:228(_ptp)
#       424    0.000    0.000    0.002    0.000 _methods.py:28(_amax)
#       184    0.000    0.000    0.001    0.000 _methods.py:32(_amin)
#       161    0.000    0.000    0.001    0.000 _methods.py:36(_sum)
#        10    0.000    0.000    0.000    0.000 _methods.py:44(_any)
#       431    0.000    0.000    0.003    0.000 _methods.py:47(_all)
#       168    0.001    0.000    0.002    0.000 _methods.py:63(_clip_dep_is_scalar_nan)
#       168    0.000    0.000    0.000    0.000 _methods.py:73(_clip_dep_is_byte_swapped)
#        84    0.001    0.000    0.001    0.000 _methods.py:78(_clip_dep_invoke_with_casting)
#        84    0.000    0.000    0.003    0.000 _methods.py:97(_clip)
#        23    0.000    0.000    0.000    0.000 _pylab_helpers.py:100(get_active)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:110(set_active)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:116(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:30(get_fig_manager)
#         1    0.000    0.000    0.001    0.001 _pylab_helpers.py:66(destroy_all)
#         2    0.000    0.000    0.000    0.000 _pylab_helpers.py:86(get_all_fig_managers)
#         2    0.000    0.000    0.000    0.000 _subplots.py:110(get_subplotspec)
#         2    0.000    0.000    0.001    0.000 _subplots.py:122(update_params)
#         2    0.000    0.000    0.031    0.016 _subplots.py:18(__init__)
#       248    0.001    0.000    0.001    0.000 _ufunc_config.py:139(geterr)
#       248    0.001    0.000    0.001    0.000 _ufunc_config.py:39(seterr)
#       124    0.000    0.000    0.000    0.000 _ufunc_config.py:437(__init__)
#       124    0.000    0.000    0.001    0.000 _ufunc_config.py:441(__enter__)
#       124    0.000    0.000    0.001    0.000 _ufunc_config.py:446(__exit__)
#     33345    0.015    0.000    0.044    0.000 abc.py:137(__instancecheck__)
#        48    0.000    0.000    0.000    0.000 abc.py:141(__subclasscheck__)
#      1102    0.000    0.000    0.000    0.000 activations.py:280(linear)
#        32    0.000    0.000    0.000    0.000 activations.py:310(get)
#       100    0.001    0.000    0.025    0.000 adam.py:142(_create_slots)
#       100    0.004    0.000    0.104    0.001 adam.py:153(_prepare_local)
#       600    0.005    0.000    0.055    0.000 adam.py:184(_resource_apply_dense)
#         1    0.000    0.000    0.000    0.000 adam.py:48(__init__)
#       100    0.001    0.000    0.011    0.000 array_grad.py:607(_ReshapeGrad)
#      1703    0.003    0.000    0.015    0.000 array_ops.py:1255(_should_not_autopack)
#      5119    0.003    0.000    0.003    0.000 array_ops.py:1261(<genexpr>)
#      1703    0.002    0.000    0.017    0.000 array_ops.py:1265(_autopacking_conversion_function)
#       100    0.000    0.000    0.003    0.000 array_ops.py:136(fill)
#       312    0.001    0.000    0.023    0.000 array_ops.py:176(identity)
#      8841    0.031    0.000    1.075    0.000 array_ops.py:2304(_constant_if_small)
#      4433    0.027    0.000    0.611    0.000 array_ops.py:2314(zeros)
#       100    0.000    0.000    0.014    0.000 array_ops.py:2466(ones_like)
#       100    0.001    0.000    0.014    0.000 array_ops.py:2529(ones_like_impl)
#      4508    0.025    0.000    0.622    0.000 array_ops.py:2542(ones)
#       583    0.003    0.000    0.022    0.000 array_ops.py:3597(squeeze)
#       583    0.001    0.000    0.027    0.000 array_ops.py:3652(squeeze_v2)
#       800    0.001    0.000    0.037    0.000 array_ops.py:435(shape)
#       900    0.005    0.000    0.041    0.000 array_ops.py:461(shape_internal)
#       200    0.000    0.000    0.006    0.000 array_ops.py:489(shape_n)
#       100    0.000    0.000    0.008    0.000 array_ops.py:515(size)
#       100    0.001    0.000    0.008    0.000 array_ops.py:547(size_internal)
#       200    0.000    0.000    0.007    0.000 array_ops.py:586(rank)
#      1802    0.005    0.000    0.144    0.000 array_ops.py:59(reshape)
#       200    0.001    0.000    0.007    0.000 array_ops.py:620(rank_internal)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1512(_array_str_implementation)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:360(_get_formatdict)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:369(<lambda>)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:413(_get_format_function)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:465(wrapper)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:482(_array2string)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:520(array2string)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:69(_make_options_dict)
#         9    0.000    0.000    0.000    0.000 arrayprint.py:703(_extendLine)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:717(_formatArray)
#      10/1    0.000    0.000    0.000    0.000 arrayprint.py:726(recurser)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:74(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:835(_none_or_positive_arg)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:844(__init__)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:871(fillFormat)
#        10    0.000    0.000    0.000    0.000 arrayprint.py:921(<genexpr>)
#        10    0.000    0.000    0.000    0.000 arrayprint.py:926(<genexpr>)
#        10    0.000    0.000    0.000    0.000 arrayprint.py:930(<genexpr>)
#        10    0.000    0.000    0.000    0.000 arrayprint.py:931(<genexpr>)
#         9    0.000    0.000    0.000    0.000 arrayprint.py:955(__call__)
#         4    0.000    0.000    0.000    0.000 artist.py:1001(get_zorder)
#       252    0.000    0.000    0.001    0.000 artist.py:1005(set_zorder)
#       690    0.000    0.000    0.000    0.000 artist.py:1020(sticky_edges)
#       140    0.001    0.000    0.001    0.000 artist.py:1043(update_from)
#       180    0.000    0.000    0.006    0.000 artist.py:1064(set)
#        16    0.000    0.000    0.000    0.000 artist.py:1171(mouseover)
#      1228    0.001    0.000    0.003    0.000 artist.py:170(convert_xunits)
#      1228    0.001    0.000    0.002    0.000 artist.py:182(convert_yunits)
#      8366    0.002    0.000    0.002    0.000 artist.py:194(axes)
#      1009    0.000    0.000    0.000    0.000 artist.py:199(axes)
# 18741/15293    0.010    0.000    0.016    0.000 artist.py:219(stale)
#        64    0.000    0.000    0.000    0.000 artist.py:252(_get_clipping_extent_bbox)
#        58    0.000    0.000    0.015    0.000 artist.py:269(get_tightbbox)
#     456/2    0.002    0.000    0.203    0.102 artist.py:30(draw_wrapper)
#      3288    0.002    0.000    0.002    0.000 artist.py:338(pchanged)
#        36    0.000    0.000    0.000    0.000 artist.py:352(is_transform_set)
#       703    0.001    0.000    0.002    0.000 artist.py:360(set_transform)
#       752    0.001    0.000    0.001    0.000 artist.py:373(get_transform)
#      1866    0.002    0.000    0.006    0.000 artist.py:49(_stale_axes_callback)
#       262    0.000    0.000    0.000    0.000 artist.py:555(get_gid)
#       114    0.000    0.000    0.000    0.000 artist.py:569(get_snap)
#         2    0.000    0.000    0.000    0.000 artist.py:580(set_snap)
#       162    0.000    0.000    0.000    0.000 artist.py:608(get_sketch_params)
#       262    0.000    0.000    0.000    0.000 artist.py:666(get_path_effects)
#       855    0.001    0.000    0.002    0.000 artist.py:673(set_figure)
#        32    0.000    0.000    0.000    0.000 artist.py:697(set_clip_box)
#        58    0.000    0.000    0.005    0.000 artist.py:709(set_clip_path)
#       836    0.007    0.000    0.010    0.000 artist.py:74(__init__)
#        80    0.000    0.000    0.000    0.000 artist.py:763(get_alpha)
#      2297    0.000    0.000    0.000    0.000 artist.py:770(get_visible)
#     18745    0.003    0.000    0.003    0.000 artist.py:774(get_animated)
#        99    0.000    0.000    0.000    0.000 artist.py:778(get_in_layout)
#       122    0.000    0.000    0.000    0.000 artist.py:789(get_clip_on)
#       122    0.000    0.000    0.000    0.000 artist.py:793(get_clip_box)
#       132    0.000    0.000    0.000    0.000 artist.py:797(get_clip_path)
#        38    0.000    0.000    0.000    0.000 artist.py:811(set_clip_on)
#       242    0.000    0.000    0.000    0.000 artist.py:828(_set_gc_clip)
#       912    0.000    0.000    0.000    0.000 artist.py:838(get_rasterized)
#       912    0.000    0.000    0.000    0.000 artist.py:858(get_agg_filter)
#       122    0.000    0.000    0.000    0.000 artist.py:893(set_alpha)
#       709    0.000    0.000    0.001    0.000 artist.py:905(set_visible)
#       849    0.004    0.000    0.018    0.000 artist.py:942(update)
#       393    0.001    0.000    0.003    0.000 artist.py:946(_update_property)
#       849    0.000    0.000    0.003    0.000 artist.py:974(<listcomp>)
#        30    0.000    0.000    0.000    0.000 artist.py:981(get_label)
#        12    0.000    0.000    0.000    0.000 artist.py:985(set_label)
#         8    0.000    0.000    0.000    0.000 axis.py:1026(_set_artist_props)
#        40    0.002    0.000    0.136    0.003 axis.py:1074(_update_ticks)
#        40    0.000    0.000    0.030    0.001 axis.py:1147(_get_tick_bboxes)
#        40    0.000    0.000    0.029    0.001 axis.py:1149(<listcomp>)
#        40    0.000    0.000    0.000    0.000 axis.py:1151(<listcomp>)
#        12    0.000    0.000    0.112    0.009 axis.py:1154(get_tightbbox)
#        36    0.000    0.000    0.002    0.000 axis.py:1174(<genexpr>)
#        12    0.000    0.000    0.000    0.000 axis.py:1180(<listcomp>)
#         8    0.000    0.000    0.125    0.016 axis.py:1195(draw)
#         4    0.000    0.000    0.034    0.008 axis.py:1250(get_majorticklabels)
#         4    0.000    0.000    0.000    0.000 axis.py:1253(<listcomp>)
#         4    0.000    0.000    0.000    0.000 axis.py:1254(<listcomp>)
#         4    0.000    0.000    0.034    0.008 axis.py:1264(get_ticklabels)
#        44    0.000    0.000    0.059    0.001 axis.py:1322(get_majorticklocs)
#        40    0.001    0.000    0.052    0.001 axis.py:1326(get_minorticklocs)
#        40    0.000    0.000    0.000    0.000 axis.py:1340(<listcomp>)
#        24    0.000    0.000    0.005    0.000 axis.py:1374(_copy_tick_props)
#        44    0.000    0.000    0.000    0.000 axis.py:1388(get_major_locator)
#        44    0.000    0.000    0.034    0.001 axis.py:1404(get_major_ticks)
#        40    0.000    0.000    0.000    0.000 axis.py:1418(get_minor_ticks)
#        12    0.000    0.000    0.013    0.001 axis.py:1432(grid)
#        12    0.000    0.000    0.000    0.000 axis.py:1462(<dictcomp>)
#        44    0.000    0.000    0.001    0.000 axis.py:1480(update_units)
#        24    0.000    0.000    0.000    0.000 axis.py:1502(_update_axisinfo)
#        24    0.000    0.000    0.000    0.000 axis.py:1536(have_units)
#       300    0.000    0.000    0.002    0.000 axis.py:1539(convert_units)
#       120    0.000    0.000    0.000    0.000 axis.py:154(<dictcomp>)
#        24    0.000    0.000    0.000    0.000 axis.py:1556(set_units)
#         4    0.000    0.000    0.000    0.000 axis.py:1582(set_label_text)
#        32    0.000    0.000    0.000    0.000 axis.py:1603(set_major_formatter)
#        32    0.000    0.000    0.000    0.000 axis.py:1619(set_minor_formatter)
#        32    0.000    0.000    0.000    0.000 axis.py:1635(set_major_locator)
#        32    0.000    0.000    0.000    0.000 axis.py:1653(set_minor_locator)
#        36    0.000    0.000    0.000    0.000 axis.py:1818(_get_ticks_position)
#       108    0.000    0.000    0.000    0.000 axis.py:1834(<genexpr>)
#        36    0.000    0.000    0.000    0.000 axis.py:1855(get_label_position)
#       344    0.000    0.000    0.002    0.000 axis.py:1881(getter)
#        60    0.000    0.000    0.065    0.001 axis.py:1928(_get_tick)
#         2    0.000    0.000    0.000    0.000 axis.py:1935(_get_label)
#         2    0.000    0.000    0.000    0.000 axis.py:1953(_get_offset_text)
#       120    0.000    0.000    0.001    0.000 axis.py:198(_set_labelrotation)
#        10    0.000    0.000    0.039    0.004 axis.py:1985(_get_tick_boxes_siblings)
#        10    0.000    0.000    0.044    0.004 axis.py:2004(_update_label_position)
#        10    0.000    0.000    0.003    0.000 axis.py:2047(_update_offset_text_position)
#        36    0.000    0.000    0.000    0.000 axis.py:2140(get_ticks_position)
#        12    0.000    0.000    0.000    0.000 axis.py:2153(get_minpos)
#       120    0.000    0.000    0.000    0.000 axis.py:216(get_tick_padding)
#        42    0.001    0.000    0.047    0.001 axis.py:2179(get_tick_space)
#        60    0.000    0.000    0.061    0.001 axis.py:2217(_get_tick)
#         2    0.000    0.000    0.000    0.000 axis.py:2224(_get_label)
#         2    0.000    0.000    0.000    0.000 axis.py:2244(_get_offset_text)
#        10    0.000    0.000    0.039    0.004 axis.py:2279(_get_tick_boxes_siblings)
#        10    0.000    0.000    0.043    0.004 axis.py:2298(_update_label_position)
#        12    0.000    0.000    0.003    0.000 axis.py:230(set_clip_path)
#        10    0.000    0.000    0.000    0.000 axis.py:2340(_update_offset_text_position)
#        12    0.000    0.000    0.000    0.000 axis.py:2460(get_minpos)
#        42    0.001    0.000    0.045    0.001 axis.py:2486(get_tick_space)
#       320    0.000    0.000    0.000    0.000 axis.py:285(get_loc)
#        48    0.000    0.000    0.043    0.001 axis.py:289(draw)
#       320    0.000    0.000    0.002    0.000 axis.py:301(set_label1)
#       320    0.000    0.000    0.002    0.000 axis.py:314(set_label2)
#       600    0.000    0.000    0.002    0.000 axis.py:325(_set_artist_props)
#        36    0.000    0.000    0.006    0.000 axis.py:332(_apply_params)
#       180    0.000    0.000    0.000    0.000 axis.py:340(<genexpr>)
#        36    0.000    0.000    0.000    0.000 axis.py:359(<dictcomp>)
#        36    0.000    0.000    0.000    0.000 axis.py:370(<dictcomp>)
#        36    0.000    0.000    0.000    0.000 axis.py:381(<dictcomp>)
#        60    0.000    0.000    0.002    0.000 axis.py:405(_get_text1_transform)
#        60    0.000    0.000    0.002    0.000 axis.py:408(_get_text2_transform)
#        60    0.000    0.000    0.001    0.000 axis.py:411(apply_tickdir)
#        60    0.000    0.000    0.008    0.000 axis.py:425(_get_text1)
#        60    0.000    0.000    0.008    0.000 axis.py:442(_get_text2)
#        60    0.000    0.000    0.015    0.000 axis.py:458(_get_tick1line)
#        60    0.000    0.000    0.013    0.000 axis.py:469(_get_tick2line)
#        60    0.001    0.000    0.016    0.000 axis.py:484(_get_gridline)
#       220    0.001    0.000    0.003    0.000 axis.py:500(update_position)
#        60    0.000    0.000    0.002    0.000 axis.py:522(_get_text1_transform)
#        60    0.000    0.000    0.002    0.000 axis.py:525(_get_text2_transform)
#        60    0.000    0.000    0.001    0.000 axis.py:528(apply_tickdir)
#        60    0.000    0.000    0.008    0.000 axis.py:543(_get_text1)
#        60    0.000    0.000    0.007    0.000 axis.py:558(_get_text2)
#       120    0.003    0.000    0.126    0.001 axis.py:56(__init__)
#        60    0.000    0.000    0.014    0.000 axis.py:573(_get_tick1line)
#        60    0.000    0.000    0.013    0.000 axis.py:588(_get_tick2line)
#        60    0.000    0.000    0.016    0.000 axis.py:602(_get_gridline)
#       220    0.001    0.000    0.003    0.000 axis.py:617(update_position)
#      12/8    0.000    0.000    0.012    0.002 axis.py:658(__get__)
#         4    0.000    0.000    0.002    0.001 axis.py:715(__init__)
#        40    0.000    0.000    0.000    0.000 axis.py:759(get_remove_overlapping_locs)
#       388    0.000    0.000    0.001    0.000 axis.py:792(get_transform)
#        72    0.000    0.000    0.000    0.000 axis.py:795(get_scale)
#        32    0.000    0.000    0.004    0.000 axis.py:798(_set_scale)
#        24    0.000    0.000    0.000    0.000 axis.py:807(limit_range_for_scale)
#        24    0.000    0.000    0.003    0.000 axis.py:819(cla)
#        32    0.000    0.000    0.000    0.000 axis.py:842(reset_ticks)
#        20    0.000    0.000    0.015    0.001 axis.py:862(set_tick_params)
#        20    0.000    0.000    0.000    0.000 axis.py:900(_translate_tick_kw)
#         4    0.000    0.000    0.007    0.002 axis.py:945(set_clip_path)
#        20    0.000    0.000    0.000    0.000 axis.py:988(get_inverted)
#        12    0.000    0.000    0.000    0.000 backend.py:1221(dtype)
#       100    0.001    0.000    0.006    0.000 backend.py:2100(mean)
#      2204    0.010    0.000    0.056    0.000 backend.py:269(learning_phase)
#      7714    0.007    0.000    0.013    0.000 backend.py:305(global_learning_phase_is_set)
#         2    0.000    0.000    0.002    0.001 backend.py:3332(batch_set_value)
#      3338    0.007    0.000    0.027    0.000 backend.py:562(get_default_graph_uid_map)
#      1102    0.001    0.000    0.003    0.000 backend.py:689(is_sparse)
#      8814    0.010    0.000    0.021    0.000 backend.py:740(name_scope)
#      8857    0.006    0.000    0.022    0.000 backend.py:829(track_variable)
#      3338    0.017    0.000    0.044    0.000 backend.py:839(unique_object_name)
#         2    0.000    0.000    0.000    0.000 backend_agg.py:102(_update_methods)
#       114    0.000    0.000    0.012    0.000 backend_agg.py:119(draw_path)
#        80    0.001    0.000    0.020    0.000 backend_agg.py:164(draw_text)
#       230    0.001    0.000    0.024    0.000 backend_agg.py:193(get_text_width_height_descent)
#        80    0.000    0.000    0.000    0.000 backend_agg.py:237(get_canvas_width_height)
#       310    0.001    0.000    0.010    0.000 backend_agg.py:241(_get_agg_font)
#       574    0.000    0.000    0.000    0.000 backend_agg.py:254(points_to_pixels)
#         6    0.000    0.000    0.000    0.000 backend_agg.py:270(option_image_nocomposite)
#         2    0.000    0.000    0.205    0.102 backend_agg.py:382(draw)
#         4    0.000    0.000    0.001    0.000 backend_agg.py:393(get_renderer)
#         2    0.000    0.000    0.264    0.132 backend_agg.py:450(print_png)
#       310    0.001    0.000    0.001    0.000 backend_agg.py:49(get_hinting_flag)
#         2    0.001    0.001    0.001    0.001 backend_agg.py:80(__init__)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1225(__init__)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1254(__init__)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:150(__init__)
#       328    0.000    0.000    0.000    0.000 backend_bases.py:154(open_group)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1581(__init__)
#       328    0.000    0.000    0.000    0.000 backend_bases.py:161(close_group)
#         4    0.000    0.000    0.000    0.000 backend_bases.py:1639(is_saving)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1656(draw_event)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1889(draw)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:1939(_get_output_canvas)
#         1    0.000    0.000    0.427    0.427 backend_bases.py:1958(print_figure)
#         7    0.000    0.000    0.000    0.000 backend_bases.py:2141(mpl_connect)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2189(mpl_disconnect)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2482(__init__)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:2500(notify_axes_change)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:2515(destroy)
#         1    0.000    0.000    0.001    0.001 backend_bases.py:3244(new_figure_manager)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:3254(new_figure_manager_given_figure)
#        80    0.000    0.000    0.000    0.000 backend_bases.py:635(flipy)
#       242    0.000    0.000    0.004    0.000 backend_bases.py:654(new_gc)
#       242    0.001    0.000    0.003    0.000 backend_bases.py:718(__init__)
#       242    0.000    0.000    0.000    0.000 backend_bases.py:759(restore)
#       242    0.000    0.000    0.000    0.000 backend_bases.py:788(get_clip_path)
#       242    0.000    0.000    0.000    0.000 backend_bases.py:798(get_dashes)
#       242    0.000    0.000    0.000    0.000 backend_bases.py:840(get_snap)
#       106    0.000    0.000    0.000    0.000 backend_bases.py:851(set_alpha)
#       162    0.000    0.000    0.000    0.000 backend_bases.py:868(set_antialiased)
#       162    0.000    0.000    0.000    0.000 backend_bases.py:873(set_capstyle)
#        68    0.000    0.000    0.000    0.000 backend_bases.py:880(set_clip_rectangle)
#       242    0.000    0.000    0.000    0.000 backend_bases.py:886(set_clip_path)
#       114    0.000    0.000    0.000    0.000 backend_bases.py:897(set_dashes)
#       348    0.000    0.000    0.001    0.000 backend_bases.py:918(set_foreground)
#       162    0.000    0.000    0.000    0.000 backend_bases.py:938(set_joinstyle)
#       162    0.000    0.000    0.000    0.000 backend_bases.py:945(set_linewidth)
#       106    0.000    0.000    0.000    0.000 backend_bases.py:949(set_url)
#       162    0.000    0.000    0.000    0.000 backend_bases.py:957(set_snap)
#       242    0.000    0.000    0.000    0.000 backend_bases.py:972(get_hatch)
#       242    0.000    0.000    0.000    0.000 backend_bases.py:976(get_hatch_path)
#       242    0.000    0.000    0.000    0.000 backend_bases.py:983(get_hatch_color)
#       242    0.000    0.000    0.000    0.000 backend_bases.py:991(get_hatch_linewidth)
#       242    0.000    0.000    0.000    0.000 backend_bases.py:995(get_sketch_params)
#      3338    0.001    0.000    0.001    0.000 backend_config.py:60(floatx)
#      1110    0.001    0.000    0.001    0.000 backend_config.py:95(image_data_format)
#         1    0.000    0.000    0.034    0.034 backend_inline.py:171(_fetch_figure_metadata)
#         1    0.000    0.000    0.034    0.034 backend_inline.py:176(<listcomp>)
#         1    0.000    0.000    0.000    0.000 backend_inline.py:186(_is_light)
#         1    0.000    0.000    0.464    0.464 backend_inline.py:19(show)
#         1    0.000    0.000    0.000    0.000 backend_inline.py:193(_is_transparent)
#         1    0.000    0.000    0.000    0.000 backend_inline.py:55(draw_if_interactive)
#      2300    0.005    0.000    0.009    0.000 backprop.py:100(get_attr)
#      2700    0.010    0.000    0.259    0.000 backprop.py:116(_gradient_function)
#     12163    0.008    0.000    0.019    0.000 backprop.py:144(_record_gradient)
#      1000    0.004    0.000    0.016    0.000 backprop.py:626(_zeros)
#      2300    0.001    0.000    0.001    0.000 backprop.py:65(op_attr_type)
#       100    0.001    0.000    0.003    0.000 backprop.py:657(_ones)
#       600    0.001    0.000    0.001    0.000 backprop.py:684(_handle_or_self)
#      2300    0.003    0.000    0.003    0.000 backprop.py:76(make_attr)
#       100    0.000    0.000    0.001    0.000 backprop.py:778(__init__)
#       100    0.000    0.000    0.001    0.000 backprop.py:801(__enter__)
#       100    0.000    0.000    0.001    0.000 backprop.py:806(__exit__)
#       100    0.000    0.000    0.001    0.000 backprop.py:811(_push_tape)
#       100    0.000    0.000    0.000    0.000 backprop.py:822(_pop_tape)
#       100    0.000    0.000    0.000    0.000 backprop.py:828(__del__)
#      2700    0.002    0.000    0.002    0.000 backprop.py:93(__init__)
#       100    0.006    0.000    0.346    0.003 backprop.py:935(gradient)
#       100    0.000    0.000    0.001    0.000 backprop.py:996(<listcomp>)
# 234848/218190    0.377    0.000    1.840    0.000 base.py:453(_method_wrapper)
#     50904    0.046    0.000    0.072    0.000 base.py:577(_maybe_initialize_trackable)
#     19918    0.004    0.000    0.004    0.000 base.py:656(_deferred_dependencies)
#     19913    0.011    0.000    0.015    0.000 base.py:671(_lookup_dependency)
#      8845    0.079    0.000   13.489    0.002 base.py:685(_add_variable_with_custom_getter)
#      8845    0.008    0.000    0.012    0.000 base.py:757(_preload_simple_restoration)
#     19913    0.076    0.000    0.386    0.000 base.py:794(_track_trackable)
#     11073    0.039    0.000    0.151    0.000 base.py:848(_handle_deferred_dependencies)
# 4408/1102    0.012    0.000    0.086    0.000 base_layer.py:1137(_clear_losses)
#         2    0.000    0.000    0.003    0.002 base_layer.py:1307(set_weights)
#      3338    0.015    0.000    0.099    0.000 base_layer.py:1727(_set_dtype_policy)
#     16534    0.013    0.000    0.017    0.000 base_layer.py:1750(_compute_dtype)
#      7714    0.029    0.000    0.372    0.000 base_layer.py:1763(_maybe_cast_inputs)
#      7714    0.029    0.000    0.190    0.000 base_layer.py:1778(f)
#      1102    0.001    0.000    0.004    0.000 base_layer.py:1792(_warn_about_input_casting)
#      7714    0.005    0.000    0.008    0.000 base_layer.py:1832(_name_scope)
#      3338    0.011    0.000    0.153    0.000 base_layer.py:1835(_init_set_name)
#      7714    0.004    0.000    0.004    0.000 base_layer.py:1925(_handle_activity_regularization)
#      7714    0.054    0.000    0.177    0.000 base_layer.py:1942(_set_mask_metadata)
#     15428    0.007    0.000    0.010    0.000 base_layer.py:1947(<genexpr>)
#      4408    0.002    0.000    0.002    0.000 base_layer.py:1959(<listcomp>)
#      3306    0.001    0.000    0.001    0.000 base_layer.py:1965(<listcomp>)
#      7714    0.030    0.000    0.214    0.000 base_layer.py:1982(_collect_input_masks)
#      7714    0.004    0.000    0.006    0.000 base_layer.py:1990(<lambda>)
#     15428    0.033    0.000    0.068    0.000 base_layer.py:1996(_call_arg_was_passed)
#      7714    0.042    0.000   15.442    0.002 base_layer.py:2118(_maybe_build)
#      6644    0.002    0.000    0.047    0.000 base_layer.py:2133(<genexpr>)
#      3322    0.002    0.000    0.003    0.000 base_layer.py:2134(<lambda>)
#    139596    0.169    0.000    0.726    0.000 base_layer.py:2184(_obj_reference_counts)
#    169518    0.068    0.000    0.133    0.000 base_layer.py:2191(_maybe_create_attribute)
# ...
#     17714    0.010    0.000    0.010    0.000 {built-in method _pywrap_tensorflow_internal.TF_OperationName}
#      8857    0.006    0.000    0.006    0.000 {built-in method _pywrap_tensorflow_internal.TF_OperationNumOutputs}
#     17714    0.009    0.000    0.009    0.000 {built-in method _pywrap_tensorflow_internal.TF_OperationOpType}
#      8857    0.006    0.000    0.006    0.000 {built-in method _pywrap_tensorflow_internal.TF_OperationOutputType}
#     17714    0.009    0.000    0.009    0.000 {built-in method _pywrap_tensorflow_internal.TF_Output_index_set}
#     17714    0.013    0.000    0.013    0.000 {built-in method _pywrap_tensorflow_internal.TF_Output_oper_set}
#     35428    0.080    0.000    0.080    0.000 {built-in method _pywrap_tensorflow_internal.TF_SetAttrValueProto}
#     17714    0.013    0.000    0.013    0.000 {built-in method _pywrap_tensorflow_internal.new_TF_Output}
#      8869    0.003    0.000    0.003    0.000 {built-in method _thread.allocate_lock}
#      8866    0.002    0.000    0.002    0.000 {built-in method _thread.get_ident}
#       300    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    0.000    0.000 {built-in method binascii.b2a_base64}
#         2    0.000    0.000    0.000    0.000 {built-in method binascii.b2a_hex}
#       808    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#     56300    0.039    0.000    0.228    0.000 {built-in method builtins.all}
#     28005    0.023    0.000    0.049    0.000 {built-in method builtins.any}
#     91304    0.013    0.000    0.013    0.000 {built-in method builtins.callable}
#      8877    0.068    0.000    0.068    0.000 {built-in method builtins.dir}
#       170    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000   24.805   24.805 {built-in method builtins.exec}
#   1491053    0.289    0.000    0.303    0.000 {built-in method builtins.getattr}
#    623848    0.286    0.000    0.356    0.000 {built-in method builtins.hasattr}
# 2797/1693    0.001    0.000    0.005    0.000 {built-in method builtins.hash}
#    280589    0.034    0.000    0.034    0.000 {built-in method builtins.id}
#   2535416    0.461    0.000    0.505    0.000 {built-in method builtins.isinstance}
#     92398    0.016    0.000    0.016    0.000 {built-in method builtins.issubclass}
#     82501    0.021    0.000    0.021    0.000 {built-in method builtins.iter}
# 247580/242070    0.041    0.000    0.044    0.000 {built-in method builtins.len}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#     12921    0.009    0.000    0.010    0.000 {built-in method builtins.max}
#       115    0.000    0.000    0.000    0.000 {built-in method builtins.min}
# 455195/294207    0.225    0.000    1.627    0.000 {built-in method builtins.next}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#        83    0.000    0.000    0.007    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#     10614    0.007    0.000    0.012    0.000 {built-in method builtins.setattr}
#     22566    0.021    0.000    0.021    0.000 {built-in method builtins.sorted}
#        77    0.000    0.000    0.004    0.000 {built-in method builtins.sum}
#       108    0.000    0.000    0.000    0.000 {built-in method builtins.vars}
#       832    0.000    0.000    0.000    0.000 {built-in method from_iterable}
#         1    0.001    0.001    0.001    0.001 {built-in method gc.collect}
#         2    0.001    0.000    0.001    0.000 {built-in method io.open}
#        80    0.000    0.000    0.000    0.000 {built-in method math.cos}
#       160    0.000    0.000    0.000    0.000 {built-in method math.floor}
#       244    0.000    0.000    0.000    0.000 {built-in method math.log10}
#       160    0.000    0.000    0.000    0.000 {built-in method math.radians}
#        80    0.000    0.000    0.000    0.000 {built-in method math.sin}
#        12    0.000    0.000    0.000    0.000 {built-in method math.sqrt}
#       761    0.002    0.000    0.002    0.000 {built-in method matplotlib._path.affine_transform}
#        77    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.count_bboxes_overlapping_bbox}
#        50    0.000    0.000    0.002    0.000 {built-in method matplotlib._path.get_path_extents}
#       385    0.001    0.000    0.002    0.000 {built-in method matplotlib._path.path_intersects_rectangle}
#        20    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.update_path_extents}
#         2    0.059    0.029    0.059    0.029 {built-in method matplotlib._png.write_png}
#       594    0.002    0.000    0.002    0.000 {built-in method numpy.arange}
#     12885    0.024    0.000    0.024    0.000 {built-in method numpy.array}
#        18    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.dragon4_positional}
# 20140/18982    0.033    0.000    0.361    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        32    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#       496    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#       248    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#      2563    0.004    0.000    0.004    0.000 {built-in method numpy.zeros}
#         8    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#       269    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.urandom}
#         4    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#      8857    0.006    0.000    0.006    0.000 {built-in method sys.exc_info}
#         4    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 {built-in method utcnow}
#     16974    0.003    0.000    0.003    0.000 {function RcParams.__getitem__ at 0x137d94170}
#     17714    0.094    0.000    0.094    0.000 {method 'ByteSize' of 'google.protobuf.pyext._message.CMessage' objects}
#     44285    0.091    0.000    0.091    0.000 {method 'CopyFrom' of 'google.protobuf.pyext._message.CMessage' objects}
#     70856    0.025    0.000    0.025    0.000 {method 'HasField' of 'google.protobuf.pyext._message.CMessage' objects}
#     26571    0.059    0.000    0.059    0.000 {method 'ParseFromString' of 'google.protobuf.pyext._message.CMessage' objects}
#     35428    0.080    0.000    0.080    0.000 {method 'SerializeToString' of 'google.protobuf.pyext._message.CMessage' objects}
#     26571    0.013    0.000    0.013    0.000 {method 'WhichOneof' of 'google.protobuf.pyext._message.CMessage' objects}
#         6    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#     91676    0.017    0.000    0.017    0.000 {method '_datatype_enum' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#      6711    0.026    0.000    0.026    0.000 {method '_numpy' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#       200    0.000    0.000    0.000    0.000 {method '_rank' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#     23837    0.015    0.000    0.015    0.000 {method '_shape_tuple' of 'tensorflow.python.framework.ops.EagerTensor' objects}
#        10    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#     26902    0.016    0.000    0.016    0.000 {method 'acquire' of '_thread.lock' objects}
#      6979    0.003    0.000    0.006    0.000 {method 'add' of 'set' objects}
#        52    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.generic' objects}
#       379    0.000    0.000    0.003    0.000 {method 'all' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#       307    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    880898    0.092    0.000    0.092    0.000 {method 'append' of 'list' objects}
#       256    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#       310    0.001    0.000    0.001    0.000 {method 'clear' of 'matplotlib.ft2font.FT2Font' objects}
#        84    0.000    0.000    0.004    0.000 {method 'clip' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedWriter' objects}
#         3    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#      8871    0.003    0.000    0.003    0.000 {method 'copy' of 'dict' objects}
#       638    0.000    0.000    0.000    0.000 {method 'copy' of 'list' objects}
#      9004    0.012    0.000    0.012    0.000 {method 'copy' of 'numpy.ndarray' objects}
#       668    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#       190    0.001    0.000    0.001    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#        80    0.002    0.000    0.002    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#        48    0.001    0.000    0.002    0.000 {method 'draw_markers' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#       114    0.008    0.000    0.011    0.000 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        80    0.002    0.000    0.002    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#     49098    0.024    0.000    0.024    0.000 {method 'encode' of 'str' objects}
#     54554    0.025    0.000    0.025    0.000 {method 'endswith' of 'str' objects}
#       688    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#        58    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#        30    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#    974721    0.123    0.000    0.123    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#        80    0.000    0.000    0.000    0.000 {method 'get_bitmap_offset' of 'matplotlib.ft2font.FT2Font' objects}
#       310    0.000    0.000    0.000    0.000 {method 'get_descent' of 'matplotlib.ft2font.FT2Font' objects}
#       230    0.000    0.000    0.000    0.000 {method 'get_width_height' of 'matplotlib.ft2font.FT2Font' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#      4408    0.001    0.000    0.001    0.000 {method 'group' of 're.Match' objects}
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#        12    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#       100    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#    106334    0.016    0.000    0.016    0.000 {method 'isidentifier' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#       182    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#     68874    0.013    0.000    0.013    0.000 {method 'items' of 'dict' objects}
#      2209    0.001    0.000    0.001    0.000 {method 'join' of 'str' objects}
#      6861    0.002    0.000    0.002    0.000 {method 'lower' of 'str' objects}
#     18385    0.039    0.000    0.039    0.000 {method 'match' of 're.Pattern' objects}
#       424    0.000    0.000    0.002    0.000 {method 'max' of 'numpy.ndarray' objects}
#       184    0.000    0.000    0.001    0.000 {method 'min' of 'numpy.ndarray' objects}
#        20    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#        84    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#        72    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.OrderedDict' objects}
#    130068    0.030    0.000    0.030    0.000 {method 'pop' of 'dict' objects}
#     57131    0.025    0.000    0.025    0.000 {method 'pop' of 'list' objects}
#       583    0.014    0.000    0.029    0.000 {method 'randint' of 'numpy.random.mtrand.RandomState' objects}
#       440    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     16576    0.191    0.000    0.203    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        10    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#     17720    0.005    0.000    0.005    0.000 {method 'release' of '_thread.lock' objects}
#       109    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'replace' of 'datetime.datetime' objects}
#       476    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#     12502    0.006    0.000    0.006    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      8857    0.002    0.000    0.002    0.000 {method 'reverse' of 'list' objects}
#        12    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#       160    0.001    0.000    0.001    0.000 {method 'round' of 'numpy.generic' objects}
#       240    0.002    0.000    0.002    0.000 {method 'round' of 'numpy.ndarray' objects}
#        50    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#       310    0.000    0.000    0.000    0.000 {method 'set_size' of 'matplotlib.ft2font.FT2Font' objects}
#       310    0.024    0.000    0.024    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
#      1342    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#       629    0.001    0.000    0.001    0.000 {method 'sort' of 'list' objects}
#        63    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#     46036    0.015    0.000    0.015    0.000 {method 'startswith' of 'str' objects}
#      6676    0.037    0.000    0.061    0.000 {method 'sub' of 're.Pattern' objects}
#       161    0.000    0.000    0.002    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HASH' objects}
#      9243    0.007    0.000    0.007    0.000 {method 'update' of 'dict' objects}
#         8    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        24    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#     21312    0.004    0.000    0.004    0.000 {method 'values' of 'dict' objects}
#     15534    0.008    0.000    0.008    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
