# %%
# %load_ext autoreload
# %autoreload 2

#import numba
import tictactoe

# %%
tictactoe.generate_action_list()
# Out:
# [[0],
#  [0, 1],
#  [0, 1, 2],
#  [0, 2],
#  [0, 2, 1],
#  [1],
#  [1, 0],
#  [1, 0, 2],
#  [1, 2],
#  [1, 2, 0],
#  [2],
#  [2, 0],
#  [2, 0, 1],
#  [2, 1],
#  [2, 1, 0]]

# %%
bellman = tictactoe.Bellman()
bellman.update([],max_actions=0)
# Out:
# Top: action_list: []
# -----------------------
# S: [0 0 0 0 0 0 0 0 0]  with action:  0  in  []
# Sa: [1 0 0 0 0 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Enter: action_list: [0]
# Top: action_list: [0]
# Return: action_list: [0]
# -----------------------
# S: [0 0 0 0 0 0 0 0 0]  with action:  1  in  []
# Sa: [0 1 0 0 0 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Enter: action_list: [1]
# Top: action_list: [1]
# Return: action_list: [1]
# -----------------------
# S: [0 0 0 0 0 0 0 0 0]  with action:  2  in  []
# Sa: [0 0 1 0 0 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Enter: action_list: [2]
# Top: action_list: [2]
# Return: action_list: [2]
# -----------------------
# S: [0 0 0 0 0 0 0 0 0]  with action:  3  in  []
# Sa: [0 0 0 1 0 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# Enter: action_list: [3]
# Top: action_list: [3]
# Return: action_list: [3]
# -----------------------
# S: [0 0 0 0 0 0 0 0 0]  with action:  4  in  []
# Sa: [0 0 0 0 1 0 0 0 0]
# ...

# %%
bellman = tictactoe.Bellman()
bellman.update([],max_actions=1,disp_flag=False)
# Out:
# -----------------------
# S: [0 0 0 0 0 0 0 0 0]  with action:  0  in  []
# Sa: [1 0 0 0 0 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [0 0 0 0 0 0 0 0 0]  with action:  1  in  []
# Sa: [0 1 0 0 0 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [0 0 0 0 0 0 0 0 0]  with action:  2  in  []
# Sa: [0 0 1 0 0 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [0 0 0 0 0 0 0 0 0]  with action:  3  in  []
# Sa: [0 0 0 1 0 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [0 0 0 0 0 0 0 0 0]  with action:  4  in  []
# Sa: [0 0 0 0 1 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [0 0 0 0 0 0 0 0 0]  with action:  5  in  []
# Sa: [0 0 0 0 0 1 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [0 0 0 0 0 0 0 0 0]  with action:  6  in  []
# Sa: [0 0 0 0 0 0 1 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# ...

# %%
bellman = tictactoe.Bellman()
bellman.update([],max_actions=2,disp_flag=False)
# Out:
# -----------------------
# S: [0 0 0 0 0 0 0 0 0]  with action:  0  in  []
# Sa: [1 0 0 0 0 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 2 0 0 0 0 0 0 0]  with action:  2  in  [0, 1]
# Sa: [1 2 1 0 0 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 2 0 0 0 0 0 0 0]  with action:  3  in  [0, 1]
# Sa: [1 2 0 1 0 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 2 0 0 0 0 0 0 0]  with action:  4  in  [0, 1]
# Sa: [1 2 0 0 1 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 2 0 0 0 0 0 0 0]  with action:  5  in  [0, 1]
# Sa: [1 2 0 0 0 1 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 2 0 0 0 0 0 0 0]  with action:  6  in  [0, 1]
# Sa: [1 2 0 0 0 0 1 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 2 0 0 0 0 0 0 0]  with action:  7  in  [0, 1]
# Sa: [1 2 0 0 0 0 0 1 0]
# [Returns]
# ...

# %%
bellman = tictactoe.Bellman()
bellman.update([],max_actions=4,disp_flag=False)
# Out:
# -----------------------
# S: [0 0 0 0 0 0 0 0 0]  with action:  0  in  []
# Sa: [1 0 0 0 0 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 2 0 0 0 0 0 0 0]  with action:  2  in  [0, 1]
# Sa: [1 2 1 0 0 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 2 1 2 0 0 0 0 0]  with action:  4  in  [0, 1, 2, 3]
# Sa: [1 2 1 2 1 0 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 2 1 2 0 0 0 0 0]  with action:  5  in  [0, 1, 2, 3]
# Sa: [1 2 1 2 0 1 0 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 2 1 2 0 0 0 0 0]  with action:  6  in  [0, 1, 2, 3]
# Sa: [1 2 1 2 0 0 1 0 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 2 1 2 0 0 0 0 0]  with action:  7  in  [0, 1, 2, 3]
# Sa: [1 2 1 2 0 0 0 1 0]
# [Returns]
# E_R = 0.0, E_V_Saa = 0.0
# -----------------------
# S: [1 2 1 2 0 0 0 0 0]  with action:  8  in  [0, 1, 2, 3]
# ...
