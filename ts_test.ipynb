# %%
# %load_ext autoreload
# %autoreload 2
import mab
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
max_action_a, regrets_a = mab.mab_bernoulli_ts_episodes(N_actions=10, N_episodes=10000, epsilon=0.1)
plt.semilogx(regrets_a)
