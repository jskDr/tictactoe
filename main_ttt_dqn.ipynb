# %%
# %load_ext autoreload
# %autoreload 2

#import numba
import tictactoe
import numpy as np
import matplotlib.pyplot as plt

# %%
tictactoe.main()
# Out:
# == Start TicTacToe Aget Framework ==
# - Developed by Sungjin Kim, 2020
#
# 0) Playing a game
# 1) Learning a new agent
# 2) Testing code
# What do you want? (0=deafult)  2
# Start to test code...
# How many episode do you want to play?(default=10000)
# 0) Play by two random players
# 1) Play for dqn player and random player
# Which playing do you want?(default=0)  1
# Playing between our dqn player and a random player
# WARNING:tensorflow:Layer mlp_agent is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# ...

# %%
tictactoe.playing_stage_dqn(N_episodes=10000, fig_flag=True)
# Out:
# WARNING:tensorflow:Layer mlp_agent_4 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 0 [0, 0, 1, 0, 1]
# S = [0,0,0, 0,0,0, 0,0,0]
# WARNING:tensorflow:Layer mlp_agent_5 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# ...
